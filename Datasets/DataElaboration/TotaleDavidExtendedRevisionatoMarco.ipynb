# %% [markdown]
# # Totale

# %% [markdown]
# ##### setup

# %%
import numpy as np
import pandas as pd
import altair as alt
import os.path
import getpass
import platform
from pandasql import sqldf

username = getpass.getuser()

print("Username: ", username)
pathPart1 = "/Users/"
pathPart2 = "/Github/SCGProject/Datasets/"
complePath = pathPart1+username+pathPart2

if platform.system() == "Darwin":
    if(username == "marcovinciguerra"):
        dfCambio = pd.read_csv(
            complePath+"/CorrectedDatasets/dfCambio.csv")

        dfClienti = pd.read_csv(
            complePath+"/CorrectedDatasets/dfClienti.csv")

        dfConsumi = pd.read_csv(
             complePath + "/CorrectedDatasets/dfConsumi.csv")

        dfCostoOrarioConsuntivo = pd.read_csv(
            complePath+"/CorrectedDatasets/dfConsuntivo.csv")

        dfCostoOrarioBudget = pd.read_csv(
            complePath+"CorrectedDatasets/dfCostoOrario.csv")

        dfImpiegoRisorse = pd.read_csv(
         complePath+"/CorrectedDatasets/dfImpiegoRisorse.csv")

        dftuttiClienti = pd.read_csv(
         complePath+"/CorrectedDatasets/dftuttiClienti.csv")

        dfVendite = pd.read_csv(
         complePath+"/CorrectedDatasets/dfVendite.csv")

    elif(username == "davidguzman"):
            pathPart1 = "/Users/"
            pathPart2 = "/documents/Github/SCGProject/Datasets/"
            complePath = pathPart1+username+pathPart2

            dfCambio = pd.read_csv(
                complePath+"/CorrectedDatasets/dfCambio.csv")

            dfClienti = pd.read_csv(
                complePath+"/CorrectedDatasets/dfClienti.csv")

            dfConsumi = pd.read_csv(
                complePath + "/CorrectedDatasets/dfConsumi.csv")

            dfCostoOrarioConsuntivo = pd.read_csv(
                complePath+"/CorrectedDatasets/dfConsuntivo.csv")

            dfCostoOrarioBudget = pd.read_csv(
                complePath+"CorrectedDatasets/dfCostoOrario.csv")

            dfImpiegoRisorse = pd.read_csv(
            complePath+"/CorrectedDatasets/dfImpiegoRisorse.csv")

            dftuttiClienti = pd.read_csv(
            complePath+"/CorrectedDatasets/dftuttiClienti.csv")

            dfVendite = pd.read_csv(
            complePath+"/CorrectedDatasets/dfVendite.csv")

elif platform.system() == "Linux":
    complePath = "/home/alinux/unibg/git_repo/SCGProject"
    pathPart1 = "/Users/"
    pathPart2 = "/documents/Github/SCGProject/Datasets/"
    complePath = pathPart1+username+pathPart2

    dfCambio = pd.read_csv(
        complePath+"/CorrectedDatasets/dfCambio.csv")

    dfClienti = pd.read_csv(
        complePath+"/CorrectedDatasets/dfClienti.csv")

    dfConsumi = pd.read_csv(
        complePath + "/CorrectedDatasets/dfConsumi.csv")

    dfCostoOrarioConsuntivo = pd.read_csv(
        complePath+"/CorrectedDatasets/dfConsuntivo.csv")

    dfCostoOrarioBudget = pd.read_csv(
        complePath+"CorrectedDatasets/dfCostoOrario.csv")

    dfImpiegoRisorse = pd.read_csv(
        complePath+"/CorrectedDatasets/dfImpiegoRisorse.csv")

    dftuttiClienti = pd.read_csv(
        complePath+"/CorrectedDatasets/dftuttiClienti.csv")

    dfVendite = pd.read_csv(
        complePath+"/CorrectedDatasets/dfVendite.csv")



dfCambio["TassoCambioMedio"] = dfCambio["TassoCambioMedio"].str.replace(',','.')
# Out:
# Username:  marcovinciguerra

# %% [markdown]
# # Ricavi

# %%
dfVendite.rename(columns = {'budget/cons':'budget'}, inplace = True)
venditeConsuntivo = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'CONSUNTIVO' or budget = 'Consuntivo'")
venditeBudget = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'BUDGET' or budget = 'Budget'")

# %%
# join with dfCambio and dfClienti
venditeConsuntivo = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
FROM venditeConsuntivo as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
where k.Anno = 'Consuntivo' or k.Anno = 'CONSUNTIVO'
''')

venditeBudget = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
FROM venditeBudget as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
where k.Anno = 'Budget' or k.Anno = 'BUDGET'
''')

# %%
sumVenditeConsuntivo = sqldf('select sum(TotaleEuro) as sumVenditaTotale from venditeConsuntivo')
sumVenditeBudget = sqldf('select sum(TotaleEuro) as sumVenditaTotale from venditeBudget')
print(sumVenditeConsuntivo)
print(sumVenditeBudget)
print(sumVenditeConsuntivo-sumVenditeBudget) #questo è lo scostamento totale dei ricavi
# Out:
#    sumVenditaTotale
# 0     507842.851413
#    sumVenditaTotale
# 0     395335.892443
#    sumVenditaTotale
# 0      112506.95897

# %% [markdown]
# # Costi

# %% [markdown]
# Materie prime

# %%
dfConsumi.rename(columns = {'Budget/cons':'budget'}, inplace = True)
consumiConsuntivo = sqldf("SELECT DISTINCT * FROM dfConsumi WHERE budget = 'CONSUNTIVO'")
consumiBudget = sqldf("SELECT DISTINCT * FROM dfConsumi WHERE budget = 'BUDGET'")
sumConsumiConsuntivo = sqldf('select sum(ImportoCostoTOTALE) from consumiConsuntivo')
sumConsumiBudget = sqldf('select sum(ImportoCostoTOTALE) from consumiBudget')
print(sumConsumiConsuntivo)
print(sumConsumiBudget)
print(sumConsumiConsuntivo-sumConsumiBudget) #questo è lo scostamento totale della materia prima
# Out:
#    sum(ImportoCostoTOTALE)
# 0                 289639.5
#    sum(ImportoCostoTOTALE)
# 0                192906.47
#    sum(ImportoCostoTOTALE)
# 0                 96733.03

# %% [markdown]
# Lavorazioni interne

# %%
impiegoConsuntivo = sqldf("SELECT DISTINCT * FROM dfImpiegoRisorse WHERE budgetConsuntivo = 'CONSUNTIVO' or budgetConsuntivo = 'Consuntivo'")
print(impiegoConsuntivo.shape)
#join con i costi orari
impiegoConsuntivo  = sqldf('''SELECT DISTINCT i.NrArticolo,i.budgetConsuntivo,i.NrOrdineProduzione,i.Descrizione,i.NrAreaProduzione,i.Risorsa,i.QuantitydiOutput,i.TempoRisorsa,c.CostoOrario
FROM impiegoConsuntivo as i join dfCostoOrarioConsuntivo as c 
on c.AreaProduzione = i.NrAreaProduzione and c.Risorsa = i.Risorsa''')
print(impiegoConsuntivo.shape)
# ci sono alcune quantità di output nulle, per gestire le sommiamo alle tuple con tutte le altre cose uguali
impiegoConsuntivo = sqldf('''select NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,sum(TempoRisorsa) as TempoRisorsa,CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoConsuntivo
group by NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,CostoOrario
order by NrArticolo
''')

del impiegoConsuntivo["NrOrdineProduzione"]
impiegoConsuntivo
# Out:
# (3791, 9)
# (3723, 9)
#       NrArticolo budgetConsuntivo        Descrizione NrAreaProduzione Risorsa  \
# 0     ART0000018       CONSUNTIVO  Controllo qualità               CQ   RIS16
# 1     ART0000018       CONSUNTIVO          Fresatura              A30    RIS5
# 2     ART0000018       CONSUNTIVO          Tornitura              A20    RIS2
# 3     ART0000041       CONSUNTIVO  Controllo qualità               CQ   RIS16
# 4     ART0000041       CONSUNTIVO          Fresatura              A30    RIS1
# ...          ...              ...                ...              ...     ...
# 3012  ART0005136       CONSUNTIVO          Fresatura              A30   RIS14
# 3013  ART0005136       CONSUNTIVO  Controllo qualità               CQ   RIS16
# 3014  ART0005136       CONSUNTIVO          Tornitura              A20   RIS13
# 3015  ART0005136       CONSUNTIVO  Controllo qualità               CQ   RIS16
# 3016  ART0005136       CONSUNTIVO          Tornitura              A20    RIS2
#
#       TempoRisorsa  CostoOrario  QuantitydiOutput
# 0           0.0000           15               2.0
# 1           1.0000           50               2.0
# 2           1.0000           80               2.0
# 3           0.0000           15               4.0
# 4           0.0001           80               4.0
# ...            ...          ...               ...
# 3012        1.2500           50               3.0
# 3013        0.0000           15               4.0
# 3014        0.5000           80               4.0
# 3015        0.0000           15               9.0
# 3016        1.0000           80               9.0
#
# [3017 rows x 8 columns]

# %%
impiegoBudget = sqldf("SELECT DISTINCT * FROM dfImpiegoRisorse WHERE budgetConsuntivo = 'BUDGET' or budgetConsuntivo = 'Budget'")
#join con i costi orari
print(impiegoBudget.shape)
impiegoBudget  = sqldf('''SELECT DISTINCT i.NrArticolo,i.budgetConsuntivo,i.NrOrdineProduzione,i.Descrizione,i.NrAreaProduzione,i.Risorsa,i.QuantitydiOutput,i.TempoRisorsa,c.CostoOrario
FROM impiegoBudget as i join dfCostoOrarioBudget as c 
on c.AreaProduzione = i.NrAreaProduzione and c.Risorsa = i.Risorsa''')
print(impiegoBudget.shape)
# righe a consuntivo sono di più che a budget e la somma dei 2 non corrisponde al numero di righe della tabella impiego risorse

# ci sono alcune quantità di output nulle, per gestire le sommiamo alle tuple con tutte le altre cose uguali
impiegoBudget = sqldf('''select NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,sum(TempoRisorsa) as TempoRisorsa,CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoBudget
group by NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,CostoOrario
order by NrArticolo
''')

del impiegoBudget["NrOrdineProduzione"]

impiegoBudget
# Out:
# (2473, 9)
# (2450, 9)
#       NrArticolo budgetConsuntivo                Descrizione NrAreaProduzione  \
# 0     ART0000018           BUDGET          Controllo qualità               CQ
# 1     ART0000018           BUDGET                  Fresatura              A30
# 2     ART0000018           BUDGET                  Tornitura              A20
# 3     ART0000041           BUDGET          Controllo qualità               CQ
# 4     ART0000041           BUDGET                  Fresatura              A30
# ...          ...              ...                        ...              ...
# 2006  ART0005136           BUDGET          Controllo qualità               CQ
# 2007  ART0005136           BUDGET                  Tornitura              A20
# 2008  ART0005136           BUDGET  Brocciatura / stozzatrice              A33
# 2009  ART0005136           BUDGET          Controllo qualità               CQ
# 2010  ART0005136           BUDGET                  Tornitura              A20
#
#      Risorsa  TempoRisorsa  CostoOrario  QuantitydiOutput
# 0      RIS16          0.00        12.75               2.0
# 1       RIS7          0.75        51.00               2.0
# 2       RIS2          1.00        68.00               2.0
# 3      RIS16          0.00        12.75               4.0
# 4       RIS7          1.25        51.00               4.0
# ...      ...           ...          ...               ...
# 2006   RIS16          0.00        12.75              10.0
# 2007   RIS14          1.25        51.00              10.0
# 2008   RIS13          0.25        42.50               1.0
# 2009   RIS16          0.00        12.75               1.0
# 2010   RIS13          0.75        68.00               1.0
#
# [2011 rows x 8 columns]

# %%
impiegoBudget

sqldf('''select NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, count(*)
from impiegoBudget 
group by NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa
order by count(*) desc''')

sqldf('''select NrArticolo, Descrizione, NrAreaProduzione, Risorsa, count(*)
from impiegoBudget 
group by NrArticolo, Descrizione, NrAreaProduzione, Risorsa
order by count(*) desc''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     718     def do_execute(self, cursor, statement, parameters, context=None):
# --> 719         cursor.execute(statement, parameters)
#     720
#
# OperationalError: no such column: NrOrdineProduzione
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandasql/sqldf.py in __call__(self, query, env)
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1273
# -> 1274             return self._exec_driver_sql(
#    1275                 statement,
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1577         dialect = self.dialect
# -> 1578         ret = self._execute_context(
#    1579             dialect,
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
# -> 1845             self._handle_dbapi_exception(
#    1846                 e, statement, parameters, cursor, context
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
# -> 2026                 util.raise_(
#    2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     718     def do_execute(self, cursor, statement, parameters, context=None):
# --> 719         cursor.execute(statement, parameters)
#     720
#
# OperationalError: (sqlite3.OperationalError) no such column: NrOrdineProduzione
# [SQL: select NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, count(*)
# from impiegoBudget
# group by NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa
# order by count(*) desc]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# /var/folders/m5/1xdj8pfj2cs3wjpc41g9qkj80000gn/T/ipykernel_4384/1470881802.py in <module>
#       1 impiegoBudget
#       2
# ----> 3 sqldf('''select NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, count(*)
#       4 from impiegoBudget
#       5 group by NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandasql/sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandasql/sqldf.py in __call__(self, query, env)
#      61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
# ---> 63                 raise PandaSQLException(ex)
#      64             except ResourceClosedError:
#      65                 # query returns nothing
#
# PandaSQLException: (sqlite3.OperationalError) no such column: NrOrdineProduzione
# [SQL: select NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, count(*)
# from impiegoBudget
# group by NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa
# order by count(*) desc]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# # Scostamento totale del guadagno (MOL)

# %%
sumImpiegoConsuntivo = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoConsuntivo WHERE TempoRisorsa>=0')
sumImpiegoBudget = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoBudget WHERE TempoRisorsa>=0')
print(sumImpiegoConsuntivo)
print(sumImpiegoBudget)
print(sumImpiegoConsuntivo-sumImpiegoBudget)
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                    359238.2962
#    sum(TempoRisorsa*CostoOrario)
# 0                   194521.50346
#    sum(TempoRisorsa*CostoOrario)
# 0                   164716.79274

# %%
print(sumVenditeConsuntivo.values[0][0])
print(sumImpiegoConsuntivo.values[0][0]+sumConsumiConsuntivo.values[0][0])
print(sumVenditeConsuntivo.values[0][0]-sumImpiegoConsuntivo.values[0][0]-sumConsumiConsuntivo.values[0][0])
print(sumVenditeBudget.values[0][0])
print(sumImpiegoBudget.values[0][0]+sumConsumiBudget.values[0][0])
print(sumVenditeBudget.values[0][0]-sumImpiegoBudget.values[0][0]-sumConsumiBudget.values[0][0])
# Out:
# 507842.8514127266
# 648877.7962
# -141034.94478727342
# 395335.8924431994
# 387427.97346000024
# 7907.918983199197

# %% [markdown]
# Senza vincoli su tempi negativi
#
# **non cambia perché per ogni tempo negativo esiste un tempo positivo uguale in modulo che, al sommare i tempi delle stesse attività, si annullano a vicenda**

# %%
sumImpiegoConsuntivo = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoConsuntivo')
sumImpiegoBudget = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoBudget')
print(sumImpiegoConsuntivo)
print(sumImpiegoBudget)
print(sumImpiegoConsuntivo-sumImpiegoBudget)
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                    359215.7962
#    sum(TempoRisorsa*CostoOrario)
# 0                   194521.50346
#    sum(TempoRisorsa*CostoOrario)
# 0                   164694.29274

# %%
print(sumVenditeConsuntivo.values[0][0])
print(sumImpiegoConsuntivo.values[0][0]+sumConsumiConsuntivo.values[0][0])
print(sumVenditeConsuntivo.values[0][0]-sumImpiegoConsuntivo.values[0][0]-sumConsumiConsuntivo.values[0][0])
print(sumVenditeBudget.values[0][0])
print(sumImpiegoBudget.values[0][0]+sumConsumiBudget.values[0][0])
print(sumVenditeBudget.values[0][0]-sumImpiegoBudget.values[0][0]-sumConsumiBudget.values[0][0])
# Out:
# 507842.8514127266
# 648855.2962
# -141012.44478727342
# 395335.8924431994
# 387427.97346000024
# 7907.918983199197

# %% [markdown]
# # Socostamento di volume

# %% [markdown]
# #### Collapse to something more manageable

# %%
# Creazione colonna ImpiegoUnitario
impiegoConsuntivo = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, Risorsa, TempoRisorsa, TempoRisorsa/QuantitydiOutput as ImpiegoUnitario, CostoOrario ,QuantitydiOutput
from impiegoConsuntivo''')

# %%
sqldf('select sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput) from impiegoConsuntivo')
# Out:
#    sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput)
# 0                                        329701.5902

# %%
sqldf('select sum(TempoRisorsa*CostoOrario) from impiegoConsuntivo')
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                    359215.7962

# %% [markdown]
# Notiamo che sono diversi, e diminiuisce se utilizziamo 'ImpiegoUnitario' questo è dovuto al fatto che ci siano dei valori uguali a 0:

# %%
x = sqldf('''select NrArticolo,budgetConsuntivo,Descrizione,NrAreaProduzione,Risorsa,TempoRisorsa,ImpiegoUnitario,CostoOrario,QuantitydiOutput, TempoRisorsa*CostoOrario, ImpiegoUnitario*CostoOrario*QuantitydiOutput
from impiegoConsuntivo''')
#in conclusione, i totali cambiano perché ci sono quantità di output nulle! quindi alcuni impieghi diventano nan
# TODO IDEA PER RISOLVERE: fare avg di CostoOrario e sum TempoRisorsa, QuantitydiOutput in quei casi in cui la descrizione è uguale ma la risorsa è diversa, il totale dovrebbe essere uguale

# %% [markdown]
# Avg out the null values

# %%
impiegoConsuntivo = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, sum(TempoRisorsa) as TempoRisorsa, avg(CostoOrario) as CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoConsuntivo
group by NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione
''')

impiegoConsuntivo = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, TempoRisorsa, TempoRisorsa/QuantitydiOutput as ImpiegoUnitario, CostoOrario ,QuantitydiOutput
from impiegoConsuntivo
''')
impiegoConsuntivo
# Out:
#       NrArticolo budgetConsuntivo  \
# 0     ART0000018       CONSUNTIVO
# 1     ART0000018       CONSUNTIVO
# 2     ART0000018       CONSUNTIVO
# 3     ART0000041       CONSUNTIVO
# 4     ART0000041       CONSUNTIVO
# ...          ...              ...
# 1281  ART0005136       CONSUNTIVO
# 1282  ART0005136       CONSUNTIVO
# 1283  ART0005136       CONSUNTIVO
# 1284  ART0005136       CONSUNTIVO
# 1285  ART0005136       CONSUNTIVO
#
#                                             Descrizione NrAreaProduzione  \
# 0                                     Controllo qualità               CQ
# 1                                             Fresatura              A30
# 2                                             Tornitura              A20
# 3                                     Controllo qualità               CQ
# 4                                             Fresatura              A30
# ...                                                 ...              ...
# 1281                                          Saldatura              A11
# 1282                                             Taglio              A10
# 1283                                          Tornitura              A20
# 1284                     Tornitura (chiedere a Massimo)              A20
# 1285  Tornitura del solo ø45 (allargare a nuova toller)              A20
#
#       TempoRisorsa  ImpiegoUnitario  CostoOrario  QuantitydiOutput
# 0           0.0000         0.000000    15.000000               2.0
# 1           1.0000         0.500000    50.000000               2.0
# 2           1.0000         0.500000    80.000000               2.0
# 3           0.0000         0.000000    15.000000               4.0
# 4           0.0001         0.000025    80.000000               4.0
# ...            ...              ...          ...               ...
# 1281       21.8550         0.496705    50.000000              44.0
# 1282       12.0000        12.000000    60.000000               1.0
# 1283      143.9091         0.266993    75.903614             539.0
# 1284        3.7500         3.750000    80.000000               1.0
# 1285        1.0000         0.125000    80.000000               8.0
#
# [1286 rows x 8 columns]

# %%
sqldf('select sum(TempoRisorsa*CostoOrario) from impiegoConsuntivo') # si mantiene quasi uguale!!
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                  359425.545873

# %%
sqldf('select sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput) from impiegoConsuntivo')
# Out:
#    sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput)
# 0                                      358735.055873

# %% [markdown]
# la piccola differenza è dovuta alla restante parte di righe con output nulle e senza altre righe con output non nullo da sommare

# %%
sqldf('select * from impiegoConsuntivo where ImpiegoUnitario is null')
# Out:
#     NrArticolo budgetConsuntivo Descrizione NrAreaProduzione  TempoRisorsa  \
# 0   ART0000151       CONSUNTIVO   Fresatura              A30        3.0000
# 1   ART0001789       CONSUNTIVO   Fresatura              A30        4.4990
# 2   ART0001872       CONSUNTIVO   Fresatura              A30        0.0001
# 3   ART0001873       CONSUNTIVO   Fresatura              A30        0.0001
# 4   ART0001939       CONSUNTIVO   Fresatura              A30        0.0001
# 5   ART0001942       CONSUNTIVO   Fresatura              A30        0.0001
# 6   ART0001945       CONSUNTIVO   Fresatura              A30        0.0001
# 7   ART0002152       CONSUNTIVO   Fresatura              A30        4.0000
# 8   ART0004146       CONSUNTIVO   Montaggio              A40        1.5000
# 9   ART0004357       CONSUNTIVO   Fresatura              A30        0.0100
# 10  ART0005136       CONSUNTIVO        None              A20        0.5000
#
#    ImpiegoUnitario  CostoOrario  QuantitydiOutput
# 0             None         50.0               0.0
# 1             None         50.0               0.0
# 2             None         80.0               0.0
# 3             None         80.0               0.0
# 4             None         80.0               0.0
# 5             None         80.0               0.0
# 6             None         80.0               0.0
# 7             None         50.0               0.0
# 8             None         50.0               0.0
# 9             None         50.0               0.0
# 10            None         80.0               0.0

# %% [markdown]
# #### ripetiamo per budget

# %%
impiegoBudget = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, sum(TempoRisorsa) as TempoRisorsa, avg(CostoOrario) as CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoBudget
group by NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione
''')

impiegoBudget = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, TempoRisorsa, TempoRisorsa/QuantitydiOutput as ImpiegoUnitario, CostoOrario ,QuantitydiOutput
from impiegoBudget
''')
impiegoBudget
# Out:
#       NrArticolo budgetConsuntivo           Descrizione NrAreaProduzione  \
# 0     ART0000018           BUDGET     Controllo qualità               CQ
# 1     ART0000018           BUDGET             Fresatura              A30
# 2     ART0000018           BUDGET             Tornitura              A20
# 3     ART0000041           BUDGET     Controllo qualità               CQ
# 4     ART0000041           BUDGET             Fresatura              A30
# ...          ...              ...                   ...              ...
# 1222  ART0005136           BUDGET  Foratura/Maschiatura              A32
# 1223  ART0005136           BUDGET             Fresatura              A30
# 1224  ART0005136           BUDGET             Montaggio              A40
# 1225  ART0005136           BUDGET       Taglio spezzoni              A20
# 1226  ART0005136           BUDGET             Tornitura              A20
#
#       TempoRisorsa  ImpiegoUnitario  CostoOrario  QuantitydiOutput
# 0             0.00         0.000000    12.750000               2.0
# 1             0.75         0.375000    51.000000               2.0
# 2             1.00         0.500000    68.000000               2.0
# 3             0.00         0.000000    12.750000               4.0
# 4             1.25         0.312500    51.000000               4.0
# ...            ...              ...          ...               ...
# 1222          3.00              NaN    42.500000               0.0
# 1223         21.33         0.888750    47.600000              24.0
# 1224          8.25              NaN    42.500000               0.0
# 1225          4.50         0.155172    68.000000              29.0
# 1226         53.75         0.163872    65.166667             328.0
#
# [1227 rows x 8 columns]

# %%
sqldf('select sum(TempoRisorsa*CostoOrario) from impiegoBudget') # si mantiene quasi uguale!!
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                  194739.149842

# %%
sqldf('select sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput) from impiegoBudget')
# Out:
#    sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput)
# 0                                      192493.776242

# %%
sqldf('select * from impiegoBudget where ImpiegoUnitario is null')
# Out:
#     NrArticolo budgetConsuntivo           Descrizione NrAreaProduzione  \
# 0   ART0000129           BUDGET             Fresatura              A30
# 1   ART0000157           BUDGET             Tornitura              A20
# 2   ART0000645           BUDGET             Fresatura              A30
# 3   ART0000883           BUDGET             Fresatura              A30
# 4   ART0001866           BUDGET             Rettifica              A34
# 5   ART0001877           BUDGET             Fresatura              A30
# 6   ART0001885           BUDGET             Fresatura              A30
# 7   ART0001917           BUDGET             Fresatura              A30
# 8   ART0003780           BUDGET             Fresatura              A30
# 9   ART0004084           BUDGET             Montaggio              A40
# 10  ART0004902           BUDGET             Fresatura              A30
# 11  ART0005136           BUDGET  Foratura/Maschiatura              A32
# 12  ART0005136           BUDGET             Montaggio              A40
#
#     TempoRisorsa ImpiegoUnitario  CostoOrario  QuantitydiOutput
# 0         0.0090            None         68.0               0.0
# 1        15.0000            None         68.0               0.0
# 2         1.0019            None         68.0               0.0
# 3         1.0000            None         42.5               0.0
# 4        10.0000            None         42.5               0.0
# 5         0.0001            None         68.0               0.0
# 6         0.0001            None         68.0               0.0
# 7         0.0090            None         68.0               0.0
# 8         1.5000            None         51.0               0.0
# 9         3.1500            None         42.5               0.0
# 10        0.0001            None         68.0               0.0
# 11        3.0000            None         42.5               0.0
# 12        8.2500            None         42.5               0.0

# %% [markdown]
# #### Merge/Join

# %%
impiegoConsuntivo.drop(['budgetConsuntivo'], axis=1, inplace=True)
impiegoBudget.drop(['budgetConsuntivo'], axis=1, inplace=True)
x = pd.merge(impiegoConsuntivo, impiegoBudget, on=['NrArticolo', 'Descrizione', 'NrAreaProduzione'], how='outer')
x
# Out:
#       NrArticolo           Descrizione NrAreaProduzione  TempoRisorsa_x  \
# 0     ART0000018     Controllo qualità               CQ          0.0000
# 1     ART0000018             Fresatura              A30          1.0000
# 2     ART0000018             Tornitura              A20          1.0000
# 3     ART0000041     Controllo qualità               CQ          0.0000
# 4     ART0000041             Fresatura              A30          0.0001
# ...          ...                   ...              ...             ...
# 1345  ART0004904             Tornitura              A20             NaN
# 1346  ART0004944             Tornitura              A20             NaN
# 1347  ART0005091             Fresatura              A30             NaN
# 1348  ART0005136  Foratura/Maschiatura              A32             NaN
# 1349  ART0005136       Taglio spezzoni              A20             NaN
#
#       ImpiegoUnitario_x  CostoOrario_x  QuantitydiOutput_x  TempoRisorsa_y  \
# 0              0.000000           15.0                 2.0            0.00
# 1              0.500000           50.0                 2.0            0.75
# 2              0.500000           80.0                 2.0            1.00
# 3              0.000000           15.0                 4.0            0.00
# 4              0.000025           80.0                 4.0            1.25
# ...                 ...            ...                 ...             ...
# 1345                NaN            NaN                 NaN            1.75
# 1346                NaN            NaN                 NaN            1.75
# 1347                NaN            NaN                 NaN            1.00
# 1348                NaN            NaN                 NaN            3.00
# 1349                NaN            NaN                 NaN            4.50
#
#       ImpiegoUnitario_y  CostoOrario_y  QuantitydiOutput_y
# 0              0.000000          12.75                 2.0
# 1              0.375000          51.00                 2.0
# 2              0.500000          68.00                 2.0
# 3              0.000000          12.75                 4.0
# 4              0.312500          51.00                 4.0
# ...                 ...            ...                 ...
# 1345           0.437500          68.00                 4.0
# 1346           0.218750          68.00                 8.0
# 1347           0.250000          42.50                 4.0
# 1348                NaN          42.50                 0.0
# 1349           0.155172          68.00                29.0
#
# [1350 rows x 11 columns]

# %%
print(sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x) from x'))
print(sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y) from x'))
# non altera i totali!!
# Out:
#    sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x)
# 0                                      358735.055873
#    sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y)
# 0                                      192493.776242

# %%
# Impiego Standard (volume a consuntivo)
sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_x) from x')
# Out:
#    sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_x)
# 0                                      310199.342647

# %%
# Impiego Effettivo (volume e impiego a consuntivo)
sqldf('select sum(ImpiegoUnitario_x*CostoOrario_y*QuantitydiOutput_x) from x')
# Out:
#    sum(ImpiegoUnitario_x*CostoOrario_y*QuantitydiOutput_x)
# 0                                      281289.915653

# %%
# Budget Effettivo (tutto a consuntivo)
sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x) from x')
# Out:
#    sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x)
# 0                                      358735.055873

# %% [markdown]
# ### Versione simplificata

# %%
impiegoConsuntivo = sqldf(''' select NrArticolo, budgetConsuntivo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, TempoRisorsa, CostoOrario, TempoRisorsa*CostoOrario as Totale ,QuantitydiOutput
from impiegoConsuntivo''')
impiegoConsuntivo = sqldf('''select NrArticolo, NrOrdineProduzione, Descrizione ,sum(Totale) as Totale, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoConsuntivo
group by NrArticolo, NrOrdineProduzione, Descrizione
''')
#Tolgo NrOrdineProduzione per semplificare il confronto
impiegoConsuntivo = sqldf('''select NrArticolo, Descrizione , Totale, QuantitydiOutput
from impiegoConsuntivo
''')

# %%
sqldf('select sum(Totale) from impiegoConsuntivo') # resta uguale al totale precedente!
# Out:
#    sum(Totale)
# 0  359215.7962

# %%
impiegoBudget = sqldf(''' select NrArticolo, budgetConsuntivo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, TempoRisorsa, CostoOrario, TempoRisorsa*CostoOrario as Totale ,QuantitydiOutput
from impiegoBudget''')
impiegoBudget = sqldf('''select NrArticolo, NrOrdineProduzione, Descrizione ,sum(Totale) as Totale, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoBudget
group by NrArticolo, NrOrdineProduzione, Descrizione
''')
#Tolgo NrOrdineProduzione per semplificare il confronto
impiegoBudget = sqldf('''select NrArticolo, Descrizione , Totale, QuantitydiOutput
from impiegoBudget
''')

# %%
sqldf('select sum(Totale) from impiegoBudget') # resta uguale al totale precedente!
# Out:
#     sum(Totale)
# 0  194521.50346

# %%
# Consuntivo diventa x e budget diventa y
x = pd.merge(impiegoConsuntivo,impiegoBudget, on = ['NrArticolo','Descrizione'], how = 'outer')
