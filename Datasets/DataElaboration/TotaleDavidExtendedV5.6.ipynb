# %% [markdown]
# # Totale

# %% [markdown]
# ##### setup

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt
import os.path
import getpass
import platform
from pandasql import sqldf
import openpyxl

username = getpass.getuser()

print("Username: ", username)
pathPart1 = "/Users/"
pathPart2 = "/Github/SCGProject/Datasets/"
complePath = pathPart1+username+pathPart2

if platform.system() == "Darwin":
    if(username == "marcovinciguerra"):
        dfCambio = pd.read_csv(
            complePath+"/CorrectedDatasets/dfCambio.csv")

        dfClienti = pd.read_csv(
            complePath+"/CorrectedDatasets/dfClienti.csv")

        dfConsumi = pd.read_csv(
             complePath + "/CorrectedDatasets/dfConsumi.csv")

        dfCostoOrarioConsuntivo = pd.read_csv(
            complePath+"/CorrectedDatasets/dfConsuntivo.csv")

        dfCostoOrarioBudget = pd.read_csv(
            complePath+"CorrectedDatasets/dfCostoOrario.csv")

        dfImpiegoRisorse = pd.read_csv(
         complePath+"/CorrectedDatasets/dfImpiegoRisorse.csv")

        dftuttiClienti = pd.read_csv(
         complePath+"/CorrectedDatasets/dftuttiClienti.csv")

        dfVendite = pd.read_csv(
         complePath+"/CorrectedDatasets/dfVendite.csv")

    elif(username == "davidguzman"):
            pathPart1 = "/Users/"
            pathPart2 = "/documents/Github/SCGProject/Datasets/"
            complePath = pathPart1+username+pathPart2

            dfCambio = pd.read_csv(
                complePath+"/CorrectedDatasets/dfCambio.csv")

            dfClienti = pd.read_csv(
                complePath+"/CorrectedDatasets/dfClienti.csv")

            dfConsumi = pd.read_csv(
                complePath + "/CorrectedDatasets/dfConsumi.csv")

            dfCostoOrarioConsuntivo = pd.read_csv(
                complePath+"/CorrectedDatasets/dfConsuntivo.csv")

            dfCostoOrarioBudget = pd.read_csv(
                complePath+"CorrectedDatasets/dfCostoOrario.csv")

            dfImpiegoRisorse = pd.read_csv(
            complePath+"/CorrectedDatasets/dfImpiegoRisorse.csv")

            dftuttiClienti = pd.read_csv(
            complePath+"/CorrectedDatasets/dftuttiClienti.csv")

            dfVendite = pd.read_csv(
            complePath+"/CorrectedDatasets/dfVendite.csv")

elif platform.system() == "Linux":
    complePath = "/home/alinux/unibg/git_repo/SCGProject"
    pathPart1 = "/Users/"
    pathPart2 = "/documents/Github/SCGProject/Datasets/"
    complePath = pathPart1+username+pathPart2
    complePath = '/home/alinux/unibg/git_repo/SCGProject/Datasets/'

    dfCambio = pd.read_csv(
        complePath+"/CorrectedDatasets/dfCambio.csv")

    dfClienti = pd.read_csv(
        complePath+"/CorrectedDatasets/dfClienti.csv")

    dfConsumi = pd.read_csv(
        complePath + "/CorrectedDatasets/dfConsumi.csv")

    dfCostoOrarioConsuntivo = pd.read_csv(
        complePath+"/CorrectedDatasets/dfConsuntivo.csv")

    dfCostoOrarioBudget = pd.read_csv(
        complePath+"CorrectedDatasets/dfCostoOrario.csv")

    dfImpiegoRisorse = pd.read_csv(
        complePath+"/CorrectedDatasets/dfImpiegoRisorse.csv")

    dftuttiClienti = pd.read_csv(
        complePath+"/CorrectedDatasets/dftuttiClienti.csv")

    dfVendite = pd.read_csv(
        complePath+"/CorrectedDatasets/dfVendite.csv")



dfCambio["TassoCambioMedio"] = dfCambio["TassoCambioMedio"].str.replace(',','.')
# Out:
# Username:  davidguzman

# %% [markdown]
# # Ricavi

# %%
dfVendite.rename(columns = {'budget/cons':'budget'}, inplace = True)
venditeConsuntivo = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'CONSUNTIVO' or budget = 'Consuntivo'")
venditeBudget = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'BUDGET' or budget = 'Budget'")

# %%
print(venditeConsuntivo.shape, venditeBudget.shape)
# Out:
# (1767, 7) (1209, 7)

# %%
# join with dfCambio and dfClienti
venditeConsuntivo = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
FROM venditeConsuntivo as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
where k.Anno = 'Consuntivo' or k.Anno = 'CONSUNTIVO'
''')

venditeBudget = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
FROM venditeBudget as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
where k.Anno = 'Budget' or k.Anno = 'BUDGET'
''')

# %%
print(venditeConsuntivo.shape, venditeBudget.shape)
# Out:
# (1767, 11) (1209, 11)

# %%
sumVenditeConsuntivo = sqldf('select sum(TotaleEuro) as sumVenditaTotale from venditeConsuntivo')
sumVenditeBudget = sqldf('select sum(TotaleEuro) as sumVenditaTotale from venditeBudget')
print(sumVenditeConsuntivo)
print(sumVenditeBudget)
print(sumVenditeConsuntivo-sumVenditeBudget) #questo è lo scostamento totale dei ricavi
# Out:
#    sumVenditaTotale
# 0     507842.851413
#    sumVenditaTotale
# 0     395335.892443
#    sumVenditaTotale
# 0      112506.95897

# %% [markdown]
# # Costi

# %% [markdown]
# Materie prime

# %%
dfConsumi.rename(columns = {'Budget/cons':'budget'}, inplace = True)
consumiConsuntivo = sqldf("SELECT DISTINCT * FROM dfConsumi WHERE budget = 'CONSUNTIVO'")
consumiBudget = sqldf("SELECT DISTINCT * FROM dfConsumi WHERE budget = 'BUDGET'")
sumConsumiConsuntivo = sqldf('select sum(ImportoCostoTOTALE) from consumiConsuntivo')
sumConsumiBudget = sqldf('select sum(ImportoCostoTOTALE) from consumiBudget')
print(sumConsumiConsuntivo)
print(sumConsumiBudget)
print(sumConsumiConsuntivo-sumConsumiBudget) #questo è lo scostamento totale della materia prima
# Out:
#    sum(ImportoCostoTOTALE)
# 0                 289639.5
#    sum(ImportoCostoTOTALE)
# 0                192906.47
#    sum(ImportoCostoTOTALE)
# 0                 96733.03

# %% [markdown]
# Lavorazioni interne

# %%
impiegoConsuntivo = sqldf("SELECT DISTINCT * FROM dfImpiegoRisorse WHERE budgetConsuntivo = 'CONSUNTIVO' or budgetConsuntivo = 'Consuntivo'")
print(impiegoConsuntivo.shape)
#join con i costi orari
impiegoConsuntivo  = sqldf('''SELECT DISTINCT i.NrArticolo,i.budgetConsuntivo,i.NrOrdineProduzione,i.Descrizione,i.NrAreaProduzione,i.Risorsa,i.QuantitydiOutput,i.TempoRisorsa,c.CostoOrario
FROM impiegoConsuntivo as i join dfCostoOrarioConsuntivo as c 
on c.AreaProduzione = i.NrAreaProduzione and c.Risorsa = i.Risorsa''')
print(impiegoConsuntivo.shape)
# ci sono alcune quantità di output nulle, per gestire le sommiamo alle tuple con tutte le altre cose uguali
impiegoConsuntivoOld = sqldf('''select NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,sum(TempoRisorsa) as TempoRisorsa,CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoConsuntivo
group by NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,CostoOrario
order by NrArticolo
''')
impiegoConsuntivo1 = impiegoConsuntivoOld.copy()
# ASSUNZIONE: la quantity di output maggiore tiene conto di tutte quelle inferiori.
# Out:
# (3791, 9)
# (3723, 9)

# %%
impiegoConsuntivoNew = sqldf('''select NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,sum(TempoRisorsa) as TempoRisorsa,CostoOrario, max(QuantitydiOutput) as QuantitydiOutput
from impiegoConsuntivo
group by NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,CostoOrario
order by NrArticolo
''')
impiegoConsuntivoNew1 = impiegoConsuntivoNew.copy()
impiegoConsuntivoNew
# Out:
#       NrArticolo budgetConsuntivo NrOrdineProduzione        Descrizione  \
# 0     ART0000018       CONSUNTIVO        ODP19-05998  Controllo qualità
# 1     ART0000018       CONSUNTIVO        ODP19-05998          Fresatura
# 2     ART0000018       CONSUNTIVO        ODP19-05998          Tornitura
# 3     ART0000041       CONSUNTIVO        ODP19-05998  Controllo qualità
# 4     ART0000041       CONSUNTIVO        ODP19-05998          Fresatura
# ...          ...              ...                ...                ...
# 3012  ART0005136       CONSUNTIVO        ODP19-06532          Fresatura
# 3013  ART0005136       CONSUNTIVO        ODP19-06533  Controllo qualità
# 3014  ART0005136       CONSUNTIVO        ODP19-06533          Tornitura
# 3015  ART0005136       CONSUNTIVO        ODP19-06688  Controllo qualità
# 3016  ART0005136       CONSUNTIVO        ODP19-06688          Tornitura
#
#      NrAreaProduzione Risorsa  TempoRisorsa  CostoOrario  QuantitydiOutput
# 0                  CQ   RIS16        0.0000           15               2.0
# 1                 A30    RIS5        1.0000           50               2.0
# 2                 A20    RIS2        1.0000           80               2.0
# 3                  CQ   RIS16        0.0000           15               4.0
# 4                 A30    RIS1        0.0001           80               4.0
# ...               ...     ...           ...          ...               ...
# 3012              A30   RIS14        1.2500           50               3.0
# 3013               CQ   RIS16        0.0000           15               4.0
# 3014              A20   RIS13        0.5000           80               4.0
# 3015               CQ   RIS16        0.0000           15               9.0
# 3016              A20    RIS2        1.0000           80               9.0
#
# [3017 rows x 9 columns]

# %%
print(sqldf('select sum(QuantitydiOutput) from impiegoConsuntivoOld'))
print(sqldf('select sum(QuantitydiOutput) from impiegoConsuntivoNew'))
# Out:
#    sum(QuantitydiOutput)
# 0                25950.0
#    sum(QuantitydiOutput)
# 0                25327.0

# %%
sqldf('select NrArticolo, NrOrdineProduzione, count(*) as c from impiegoConsuntivoNew group by NrArticolo, NrOrdineProduzione order by c')
# Out:
#       NrArticolo NrOrdineProduzione  c
# 0     ART0000116        ODP18-03472  1
# 1     ART0000116        ODP18-05889  1
# 2     ART0000119        ODP19-04430  1
# 3     ART0000121        ODP18-03469  1
# 4     ART0000128        ODP18-03529  1
# ...          ...                ... ..
# 1236  ART0005136        ODP19-01954  5
# 1237  ART0000043        ODP19-05998  6
# 1238  ART0001731        ODP18-04233  6
# 1239  ART0002360        ODP19-06224  6
# 1240  ART0004889        ODP18-06579  7
#
# [1241 rows x 3 columns]

# %%
impiegoBudget = sqldf("SELECT DISTINCT * FROM dfImpiegoRisorse WHERE budgetConsuntivo = 'BUDGET' or budgetConsuntivo = 'Budget'")
#join con i costi orari
print(impiegoBudget.shape)
impiegoBudget = sqldf('''SELECT DISTINCT i.NrArticolo,i.budgetConsuntivo,i.NrOrdineProduzione,i.Descrizione,i.NrAreaProduzione,i.Risorsa,i.QuantitydiOutput,i.TempoRisorsa,c.CostoOrario
FROM impiegoBudget as i join dfCostoOrarioBudget as c 
on c.AreaProduzione = i.NrAreaProduzione and c.Risorsa = i.Risorsa''')
print(impiegoBudget.shape)
# righe a consuntivo sono di più che a budget e la somma dei 2 non corrisponde al numero di righe della tabella impiego risorse

# ci sono alcune quantità di output nulle, per gestire le sommiamo alle tuple con tutte le altre cose uguali
impiegoBudgetOld = sqldf('''select NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,sum(TempoRisorsa) as TempoRisorsa,CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoBudget
group by NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,CostoOrario
order by NrArticolo
''')
impiegoBudget1 = impiegoBudgetOld.copy()

impiegoBudgetNew = sqldf('''select NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,sum(TempoRisorsa) as TempoRisorsa,CostoOrario, max(QuantitydiOutput) as QuantitydiOutput
from impiegoBudget
group by NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,CostoOrario
order by NrArticolo
''')
impiegoBudgetNew1 = impiegoBudgetNew.copy()
# Out:
# (2473, 9)
# (2450, 9)

# %%
print(sqldf('select sum(QuantitydiOutput) from impiegoBudgetOld'))
print(sqldf('select sum(QuantitydiOutput) from impiegoBudgetNew'))
# Out:
#    sum(QuantitydiOutput)
# 0                15768.5
#    sum(QuantitydiOutput)
# 0               15580.25

# %%
impiegoBudgetNew = sqldf('''select NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,sum(TempoRisorsa) as TempoRisorsa,CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
from impiegoBudgetNew
group by NrArticolo,budgetConsuntivo,NrOrdineProduzione,Descrizione,NrAreaProduzione,Risorsa,CostoOrario
order by NrArticolo
''')

# %%
impiegoBudgetNew

sqldf('''select NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, count(*)
from impiegoBudgetNew 
group by NrArticolo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa
order by count(*) desc''')

sqldf('''select NrArticolo, Descrizione, NrAreaProduzione, Risorsa, count(*)
from impiegoBudgetNew 
group by NrArticolo, Descrizione, NrAreaProduzione, Risorsa
order by count(*) desc''')
# Out:
#       NrArticolo                Descrizione NrAreaProduzione Risorsa  count(*)
# 0     ART0005136          Controllo qualità               CQ   RIS16        19
# 1     ART0005136                  Tornitura              A20    RIS2        13
# 2     ART0000795          Controllo qualità               CQ   RIS16        11
# 3     ART0000762          Controllo qualità               CQ   RIS16         9
# 4     ART0000782          Controllo qualità               CQ   RIS16         8
# ...          ...                        ...              ...     ...       ...
# 1395  ART0005136  Brocciatura / stozzatrice              A33    RIS2         1
# 1396  ART0005136       Foratura/Maschiatura              A32    RIS9         1
# 1397  ART0005136                  Fresatura              A30    RIS1         1
# 1398  ART0005136                  Fresatura              A30   RIS13         1
# 1399  ART0005136            Taglio spezzoni              A20    RIS2         1
#
# [1400 rows x 5 columns]

# %% [markdown]
# # Scostamento totale

# %%
sumImpiegoConsuntivo = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoConsuntivoNew WHERE TempoRisorsa>=0')
sumImpiegoBudget = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoBudgetNew WHERE TempoRisorsa>=0')
print(sumImpiegoConsuntivo)
print(sumImpiegoBudget)
print(sumImpiegoConsuntivo-sumImpiegoBudget)
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                    359238.2962
#    sum(TempoRisorsa*CostoOrario)
# 0                   194521.50346
#    sum(TempoRisorsa*CostoOrario)
# 0                   164716.79274

# %%
print(sumVenditeConsuntivo.values[0][0])
print(sumImpiegoConsuntivo.values[0][0]+sumConsumiConsuntivo.values[0][0])
print(sumVenditeConsuntivo.values[0][0]-sumImpiegoConsuntivo.values[0][0]-sumConsumiConsuntivo.values[0][0])
print(sumVenditeBudget.values[0][0])
print(sumImpiegoBudget.values[0][0]+sumConsumiBudget.values[0][0])
print(sumVenditeBudget.values[0][0]-sumImpiegoBudget.values[0][0]-sumConsumiBudget.values[0][0])
# Out:
# 507842.8514127266
# 648877.7962
# -141034.94478727342
# 395335.8924431994
# 387427.97346000024
# 7907.918983199197

# %% [markdown]
# Senza vincoli su tempi negativi
#
# **non cambia perché per ogni tempo negativo esiste un tempo positivo uguale in modulo che, al sommare i tempi delle stesse attività, si annullano a vicenda**

# %%
sumImpiegoConsuntivo = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoConsuntivoNew')
sumImpiegoBudget = sqldf(
    'SELECT sum(TempoRisorsa*CostoOrario) FROM impiegoBudgetNew')
print(sumImpiegoConsuntivo)
print(sumImpiegoBudget)
print(sumImpiegoConsuntivo-sumImpiegoBudget)
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                    359215.7962
#    sum(TempoRisorsa*CostoOrario)
# 0                   194521.50346
#    sum(TempoRisorsa*CostoOrario)
# 0                   164694.29274

# %%
print(sumVenditeConsuntivo.values[0][0])
print(sumImpiegoConsuntivo.values[0][0]+sumConsumiConsuntivo.values[0][0])
print(sumVenditeConsuntivo.values[0][0]-sumImpiegoConsuntivo.values[0][0]-sumConsumiConsuntivo.values[0][0])
print(sumVenditeBudget.values[0][0])
print(sumImpiegoBudget.values[0][0]+sumConsumiBudget.values[0][0])
print(sumVenditeBudget.values[0][0]-sumImpiegoBudget.values[0][0]-sumConsumiBudget.values[0][0])
# Out:
# 507842.8514127266
# 648855.2962
# -141012.44478727342
# 395335.8924431994
# 387427.97346000024
# 7907.918983199197

# %% [markdown]
# # Socostamento di volume, impiego e prezzo per le Lavorazioni

# %% [markdown]
# #### consuntivo

# %%
# Creazione colonna ImpiegoUnitario
impiegoConsuntivoNew = sqldf(''' select NrArticolo, budgetConsuntivo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, TempoRisorsa, TempoRisorsa/QuantitydiOutput as ImpiegoUnitario, CostoOrario ,QuantitydiOutput
from impiegoConsuntivoNew''')
impiegoConsuntivoNew
# Out:
#       NrArticolo budgetConsuntivo NrOrdineProduzione        Descrizione  \
# 0     ART0000018       CONSUNTIVO        ODP19-05998  Controllo qualità
# 1     ART0000018       CONSUNTIVO        ODP19-05998          Fresatura
# 2     ART0000018       CONSUNTIVO        ODP19-05998          Tornitura
# 3     ART0000041       CONSUNTIVO        ODP19-05998  Controllo qualità
# 4     ART0000041       CONSUNTIVO        ODP19-05998          Fresatura
# ...          ...              ...                ...                ...
# 3012  ART0005136       CONSUNTIVO        ODP19-06532          Fresatura
# 3013  ART0005136       CONSUNTIVO        ODP19-06533  Controllo qualità
# 3014  ART0005136       CONSUNTIVO        ODP19-06533          Tornitura
# 3015  ART0005136       CONSUNTIVO        ODP19-06688  Controllo qualità
# 3016  ART0005136       CONSUNTIVO        ODP19-06688          Tornitura
#
#      NrAreaProduzione Risorsa  TempoRisorsa  ImpiegoUnitario  CostoOrario  \
# 0                  CQ   RIS16        0.0000         0.000000           15
# 1                 A30    RIS5        1.0000         0.500000           50
# 2                 A20    RIS2        1.0000         0.500000           80
# 3                  CQ   RIS16        0.0000         0.000000           15
# 4                 A30    RIS1        0.0001         0.000025           80
# ...               ...     ...           ...              ...          ...
# 3012              A30   RIS14        1.2500         0.416667           50
# 3013               CQ   RIS16        0.0000         0.000000           15
# 3014              A20   RIS13        0.5000         0.125000           80
# 3015               CQ   RIS16        0.0000         0.000000           15
# 3016              A20    RIS2        1.0000         0.111111           80
#
#       QuantitydiOutput
# 0                  2.0
# 1                  2.0
# 2                  2.0
# 3                  4.0
# 4                  4.0
# ...                ...
# 3012               3.0
# 3013               4.0
# 3014               4.0
# 3015               9.0
# 3016               9.0
#
# [3017 rows x 10 columns]

# %% [markdown]
# Avg out the null values

# %%
impiegoConsuntivoNew = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, sum(TempoRisorsa) as TempoRisorsa, avg(CostoOrario) as CostoOrario, max(QuantitydiOutput) as QuantitydiOutput
from impiegoConsuntivoNew
group by NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione
''')
impiegoConsuntivo = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, TempoRisorsa, (TempoRisorsa/QuantitydiOutput) as ImpiegoUnitario, CostoOrario,QuantitydiOutput
from impiegoConsuntivoNew
order by NrArticolo
''')

# %%
sqldf('select sum(TempoRisorsa*CostoOrario) from impiegoConsuntivo') # si mantiene quasi uguale!!
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                  359425.545873

# %%
sqldf('select sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput) from impiegoConsuntivo')
# Out:
#    sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput)
# 0                                      358735.055873

# %% [markdown]
# la piccola differenza è dovuta alla restante parte di righe con output nulle e senza altre righe con output non nullo da sommare

# %%
sqldf('select * from impiegoConsuntivo where ImpiegoUnitario is null')
# Out:
#     NrArticolo budgetConsuntivo Descrizione NrAreaProduzione  TempoRisorsa  \
# 0   ART0000151       CONSUNTIVO   Fresatura              A30        3.0000
# 1   ART0001789       CONSUNTIVO   Fresatura              A30        4.4990
# 2   ART0001872       CONSUNTIVO   Fresatura              A30        0.0001
# 3   ART0001873       CONSUNTIVO   Fresatura              A30        0.0001
# 4   ART0001939       CONSUNTIVO   Fresatura              A30        0.0001
# 5   ART0001942       CONSUNTIVO   Fresatura              A30        0.0001
# 6   ART0001945       CONSUNTIVO   Fresatura              A30        0.0001
# 7   ART0002152       CONSUNTIVO   Fresatura              A30        4.0000
# 8   ART0004146       CONSUNTIVO   Montaggio              A40        1.5000
# 9   ART0004357       CONSUNTIVO   Fresatura              A30        0.0100
# 10  ART0005136       CONSUNTIVO        None              A20        0.5000
#
#    ImpiegoUnitario  CostoOrario  QuantitydiOutput
# 0             None         50.0               0.0
# 1             None         50.0               0.0
# 2             None         80.0               0.0
# 3             None         80.0               0.0
# 4             None         80.0               0.0
# 5             None         80.0               0.0
# 6             None         80.0               0.0
# 7             None         50.0               0.0
# 8             None         50.0               0.0
# 9             None         50.0               0.0
# 10            None         80.0               0.0

# %% [markdown]
# #### ripetiamo per budget

# %%
impiegoBudgetNew = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, sum(TempoRisorsa) as TempoRisorsa, avg(CostoOrario) as CostoOrario, max(QuantitydiOutput) as QuantitydiOutput
from impiegoBudgetNew
group by NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione
''')
impiegoBudget = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, TempoRisorsa, (TempoRisorsa/QuantitydiOutput) as ImpiegoUnitario, CostoOrario,QuantitydiOutput
from impiegoBudgetNew
order by NrArticolo
''')

# %%
sqldf('select sum(TempoRisorsa*CostoOrario) from impiegoBudget') # si mantiene quasi uguale!!
# Out:
#    sum(TempoRisorsa*CostoOrario)
# 0                  194739.149842

# %%
sqldf('select sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput) from impiegoBudget')
# Out:
#    sum(ImpiegoUnitario*CostoOrario*QuantitydiOutput)
# 0                                      192493.776242

# %%
sqldf('select * from impiegoBudget where ImpiegoUnitario is null')
# Out:
#     NrArticolo budgetConsuntivo           Descrizione NrAreaProduzione  \
# 0   ART0000129           BUDGET             Fresatura              A30
# 1   ART0000157           BUDGET             Tornitura              A20
# 2   ART0000645           BUDGET             Fresatura              A30
# 3   ART0000883           BUDGET             Fresatura              A30
# 4   ART0001866           BUDGET             Rettifica              A34
# 5   ART0001877           BUDGET             Fresatura              A30
# 6   ART0001885           BUDGET             Fresatura              A30
# 7   ART0001917           BUDGET             Fresatura              A30
# 8   ART0003780           BUDGET             Fresatura              A30
# 9   ART0004084           BUDGET             Montaggio              A40
# 10  ART0004902           BUDGET             Fresatura              A30
# 11  ART0005136           BUDGET  Foratura/Maschiatura              A32
# 12  ART0005136           BUDGET             Montaggio              A40
#
#     TempoRisorsa ImpiegoUnitario  CostoOrario  QuantitydiOutput
# 0         0.0090            None         68.0               0.0
# 1        15.0000            None         68.0               0.0
# 2         1.0019            None         68.0               0.0
# 3         1.0000            None         42.5               0.0
# 4        10.0000            None         42.5               0.0
# 5         0.0001            None         68.0               0.0
# 6         0.0001            None         68.0               0.0
# 7         0.0090            None         68.0               0.0
# 8         1.5000            None         51.0               0.0
# 9         3.1500            None         42.5               0.0
# 10        0.0001            None         68.0               0.0
# 11        3.0000            None         42.5               0.0
# 12        8.2500            None         42.5               0.0

# %% [markdown]
# #### Merge/Join

# %%
impiegoConsuntivo.drop(['budgetConsuntivo'], axis=1, inplace=True)
impiegoBudget.drop(['budgetConsuntivo'], axis=1, inplace=True)
x = pd.merge(impiegoConsuntivo, impiegoBudget, on=['NrArticolo', 'Descrizione', 'NrAreaProduzione'], how='outer')
x
# Out:
#       NrArticolo           Descrizione NrAreaProduzione  TempoRisorsa_x  \
# 0     ART0000018     Controllo qualità               CQ          0.0000
# 1     ART0000018             Fresatura              A30          1.0000
# 2     ART0000018             Tornitura              A20          1.0000
# 3     ART0000041     Controllo qualità               CQ          0.0000
# 4     ART0000041             Fresatura              A30          0.0001
# ...          ...                   ...              ...             ...
# 1345  ART0004904             Tornitura              A20             NaN
# 1346  ART0004944             Tornitura              A20             NaN
# 1347  ART0005091             Fresatura              A30             NaN
# 1348  ART0005136  Foratura/Maschiatura              A32             NaN
# 1349  ART0005136       Taglio spezzoni              A20             NaN
#
#       ImpiegoUnitario_x  CostoOrario_x  QuantitydiOutput_x  TempoRisorsa_y  \
# 0              0.000000           15.0                 2.0            0.00
# 1              0.500000           50.0                 2.0            0.75
# 2              0.500000           80.0                 2.0            1.00
# 3              0.000000           15.0                 4.0            0.00
# 4              0.000025           80.0                 4.0            1.25
# ...                 ...            ...                 ...             ...
# 1345                NaN            NaN                 NaN            1.75
# 1346                NaN            NaN                 NaN            1.75
# 1347                NaN            NaN                 NaN            1.00
# 1348                NaN            NaN                 NaN            3.00
# 1349                NaN            NaN                 NaN            4.50
#
#       ImpiegoUnitario_y  CostoOrario_y  QuantitydiOutput_y
# 0              0.000000          12.75                 2.0
# 1              0.375000          51.00                 2.0
# 2              0.500000          68.00                 2.0
# 3              0.000000          12.75                 4.0
# 4              0.312500          51.00                 4.0
# ...                 ...            ...                 ...
# 1345           0.437500          68.00                 4.0
# 1346           0.218750          68.00                 8.0
# 1347           0.250000          42.50                 4.0
# 1348                NaN          42.50                 0.0
# 1349           0.155172          68.00                29.0
#
# [1350 rows x 11 columns]

# %%
c = sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x) from x').iloc[0][0]
b = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y) from x').iloc[0][0]
print(c)
print(b)
print(c-b)
# non altera i totali!!
# Out:
# 358735.05587289936
# 192493.7762416667
# 166241.27963123267

# %%
#Budget Standard
BudgetStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y) from x').iloc[0][0]
# Impiego Standard (volume a consuntivo)
ImpiegoStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_x) from x').iloc[0][0]
# Impiego Effettivo (volume e impiego a consuntivo)
ImpiegoEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_y*QuantitydiOutput_x) from x').iloc[0][0]
# Budget Effettivo (tutto a consuntivo)
BudgetEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x) from x').iloc[0][0]
print(BudgetStandardLav)
print(ImpiegoStandardLav)
print(ImpiegoEffettivoLav)
print(BudgetEffettivoLav)
# Out:
# 192493.7762416667
# 250080.51605938777
# 281289.91565333324
# 358735.05587289936

# %%
sqldf('select ImpiegoUnitario_y,CostoOrario_y,QuantitydiOutput_x from x order by QuantitydiOutput_x desc')
# Out:
#       ImpiegoUnitario_y  CostoOrario_y  QuantitydiOutput_x
# 0              0.000000      12.750000               116.0
# 1              0.020455      68.000000               116.0
# 2              0.000000      12.750000               115.0
# 3              1.047170      63.750000               115.0
# 4              0.129167      53.833333               110.0
# ...                 ...            ...                 ...
# 1345           0.437500      68.000000                 NaN
# 1346           0.218750      68.000000                 NaN
# 1347           0.250000      42.500000                 NaN
# 1348                NaN      42.500000                 NaN
# 1349           0.155172      68.000000                 NaN
#
# [1350 rows x 3 columns]

# %%
#Scostamenti
ScostamentoVolumeLav = ImpiegoStandardLav-b
ScostamentoImpiegoLav = ImpiegoEffettivoLav-ImpiegoStandardLav
ScostamentoPrezzoLav = BudgetEffettivoLav-ImpiegoEffettivoLav
print(ScostamentoVolumeLav)
print(ScostamentoImpiegoLav)
print(ScostamentoPrezzoLav)
print(ScostamentoVolumeLav+ScostamentoImpiegoLav+ScostamentoPrezzoLav)
# Out:
# 57586.73981772107
# 31209.399593945476
# 77445.14021956612
# 166241.27963123267

# %% [markdown]
# # Socostamento di volume, impiego e prezzo per le materie prime

# %% [markdown]
# #### Group by CodiceMP

# %% [markdown]
# se non facciamo qualche group by a priori si sdoppiano le righe, proviamo prima con CodiceMP

# %%
consumiConsuntivoUnitByMP = sqldf('''select CodiceMP, NrArticolo, NrDocumento as NrOrdineProduzione, sum(QuantityMPImpiegata) as QuantityMPImpiegata, sum(ImportoCostoTOTALE) as ImportoCostoTOTALE
from consumiConsuntivo     
group by CodiceMP, NrArticolo, NrOrdineProduzione''')
consumiBudgetUnitByMP = sqldf('''select CodiceMP, NrArticolo,NrDocumento as NrOrdineProduzione, sum(QuantityMPImpiegata) as QuantityMPImpiegata, sum(ImportoCostoTOTALE) as ImportoCostoTOTALE
from consumiBudget     
group by CodiceMP, NrArticolo,NrOrdineProduzione''')
consumiConsuntivoUnitByMP
# Out:
#         CodiceMP  NrArticolo NrOrdineProduzione  QuantityMPImpiegata  \
# 0     ART0000771  ART0005136        ODP19-01043                  1.0
# 1     ART0000809  ART0005136        ODP19-01043                  2.0
# 2     ART0001066  ART0003099        ODP18-08457               1064.0
# 3     ART0001068  ART0004671        ODP19-04541                190.0
# 4     ART0001073  ART0002240        ODP18-06051                184.0
# ...          ...         ...                ...                  ...
# 2766  ART0007130  ART0001228        ODP19-06232                 15.0
# 2767  ART0007133  ART0005136        ODP19-06532                  3.0
# 2768  ART0007141  ART0002191        ODP19-06418                  2.0
# 2769  ART0007148  ART0002619        ODP19-05754                  2.0
# 2770  ART0007166  ART0000877        ODP19-06659                  3.0
#
#       ImportoCostoTOTALE
# 0                 230.95
# 1                1122.70
# 2                   1.99
# 3                   6.84
# 4                  15.95
# ...                  ...
# 2766               22.50
# 2767                0.00
# 2768               13.00
# 2769               60.00
# 2770              107.45
#
# [2771 rows x 5 columns]

# %% [markdown]
# ##### ritrovare volumi di produzione

# %% [markdown]
# ordine a ritroso delle fasi:
# - controllo qualità
# - montaggio e test
# - rettifica
# - nichelatura / anodizzazione
# - cromatura
# - Tornitura + fresatura

# %%
sqldf('select distinct Descrizione from impiegoConsuntivoNew order by Descrizione')
# Out:
#                                           Descrizione
# 0                                                None
# 1                           Brocciatura / stozzatrice
# 2                                   Controllo qualità
# 3                                           Fresatura
# 4                          Fresatura (sbavatura fori)
# 5                        Fresatura (sistemazione ore)
# 6                                           Montaggio
# 7                                           Piegatura
# 8                              Preparazione materiale
# 9             Preparazione materiale/taglio/sbavatura
# 10                                          Saldatura
# 11                                             Taglio
# 12                                          Tornitura
# 13            Tornitura (anche delle bussole saldate)
# 14                     Tornitura (chiedere a Massimo)
# 15  Tornitura del solo ø45 (allargare a nuova toller)
# 16                          Verniciatura (interna 4M)

# %%
sqldf('select distinct Descrizione from impiegoBudgetNew order by Descrizione')
# Out:
#                  Descrizione
# 0  Brocciatura / stozzatrice
# 1          Controllo qualità
# 2       Foratura/Maschiatura
# 3                  Fresatura
# 4                  Montaggio
# 5     Preparazione materiale
# 6                  Rettifica
# 7                  Saldatura
# 8            Taglio spezzoni
# 9                  Tornitura

# %%
temp = sqldf('''select a.CodiceMP,a.NrArticolo,a.NrOrdineProduzione,a.QuantityMPImpiegata,a.ImportoCostoTOTALE,
( select max(QuantitydiOutput) from impiegoConsuntivoNew1  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione and Descrizione = "Controllo qualità" )
as QuantitydiOutput
from consumiConsuntivoUnitByMP as a''')
temp1 = sqldf('''select a.CodiceMP,a.NrArticolo,a.NrOrdineProduzione,a.QuantityMPImpiegata,a.ImportoCostoTOTALE,
( select max(QuantitydiOutput) from impiegoConsuntivoNew1  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione and Descrizione = "Montaggio" )
as QuantitydiOutput
from temp as a where a.QuantitydiOutput is null''')
temp2 = sqldf('''select a.CodiceMP,a.NrArticolo,a.NrOrdineProduzione,a.QuantityMPImpiegata,a.ImportoCostoTOTALE,
( select max(QuantitydiOutput) from impiegoConsuntivoNew1  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione and Descrizione = "Rettifica" )
as QuantitydiOutput
from temp1 as a where a.QuantitydiOutput is null''')

# %%
temp3 = sqldf('''select a.CodiceMP,a.NrArticolo,a.NrOrdineProduzione,a.QuantityMPImpiegata,a.ImportoCostoTOTALE,
( select max(QuantitydiOutput) from (select max(QuantitydiOutput) as QuantitydiOutput from impiegoConsuntivoNew1  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione and Descrizione = "Saldatura" union
  select max(QuantitydiOutput) as QuantitydiOutput from impiegoConsuntivoNew1  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione and Descrizione = "tornitura"  union
  select max(QuantitydiOutput) as QuantitydiOutput from impiegoConsuntivoNew1  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione and Descrizione = "fresatura")
)
as QuantitydiOutput
from temp2 as a where a.QuantitydiOutput is null''')
tempf = sqldf('''select * from temp union 
select * from temp1 union 
select * from temp2 union 
select * from temp3''')
tempf = sqldf('select distinct * from tempf where QuantitydiOutput is not null')
tempf = sqldf('''select distinct CodiceMP,NrArticolo,sum(QuantityMPImpiegata) as QuantityMPImpiegata,sum(ImportoCostoTOTALE) as ImportoCostoTOTALE ,QuantitydiOutput 
from tempf group by CodiceMP,NrArticolo''')
tempf
# Out:
#         CodiceMP  NrArticolo  QuantityMPImpiegata  ImportoCostoTOTALE  \
# 0     ART0000771  ART0005136                  1.0              230.95
# 1     ART0000809  ART0005136                  2.0             1122.70
# 2     ART0001066  ART0003099               1064.0                1.99
# 3     ART0001068  ART0004671                190.0                6.84
# 4     ART0001073  ART0002554                 78.0                6.31
# ...          ...         ...                  ...                 ...
# 1007  ART0007102  ART0000635                 10.0               88.00
# 1008  ART0007130  ART0001228                 15.0               22.50
# 1009  ART0007133  ART0005136                  3.0                0.00
# 1010  ART0007141  ART0002191                  2.0               13.00
# 1011  ART0007148  ART0002619                  2.0               60.00
#
#       QuantitydiOutput
# 0                  2.0
# 1                  2.0
# 2                 19.0
# 3                  5.0
# 4                  3.0
# ...                ...
# 1007              10.0
# 1008              15.0
# 1009               3.0
# 1010               2.0
# 1011               2.0
#
# [1012 rows x 5 columns]

# %%
temp = sqldf('''select a.CodiceMP,a.NrArticolo,a.NrOrdineProduzione,a.QuantityMPImpiegata,a.ImportoCostoTOTALE,
 (select max(QuantitydiOutput) from impiegoConsuntivoNew  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione) as QuantitydiOutput
 from consumiConsuntivoUnitByMP as a''')
temp = sqldf('''select distinct CodiceMP,NrArticolo,sum(QuantityMPImpiegata) as QuantityMPImpiegata,sum(ImportoCostoTOTALE) as ImportoCostoTOTALE ,QuantitydiOutput 
from temp group by CodiceMP,NrArticolo''')
consumiConsuntivoVolProd = sqldf('''select distinct CodiceMP,NrArticolo,QuantityMPImpiegata/QuantitydiOutput as ImpiegoPerPezzo,ImportoCostoTOTALE/QuantityMPImpiegata as CostoPerUnitaMis,QuantitydiOutput, ImportoCostoTOTALE
from temp group by CodiceMP,NrArticolo''')

temp = sqldf('''select a.CodiceMP,a.NrArticolo,a.NrOrdineProduzione,a.QuantityMPImpiegata,a.ImportoCostoTOTALE,
 (select max(QuantitydiOutput) from impiegoBudgetNew  where a.NrArticolo = NrArticolo and a.NrOrdineProduzione = NrOrdineProduzione) as QuantitydiOutput
 from consumiBudgetUnitByMP as a''')
temp = sqldf('''select distinct CodiceMP,NrArticolo,sum(QuantityMPImpiegata) as QuantityMPImpiegata,sum(ImportoCostoTOTALE) as ImportoCostoTOTALE ,QuantitydiOutput 
from temp group by CodiceMP,NrArticolo''')
consumiBudgetVolProd  = sqldf('''select distinct CodiceMP,NrArticolo,QuantityMPImpiegata/QuantitydiOutput as ImpiegoPerPezzo,ImportoCostoTOTALE/QuantityMPImpiegata as CostoPerUnitaMis,QuantitydiOutput, ImportoCostoTOTALE
from temp group by CodiceMP,NrArticolo''')

consumiConsuntivoVolProd
# Out:
#         CodiceMP  NrArticolo  ImpiegoPerPezzo  CostoPerUnitaMis  \
# 0     ART0000771  ART0005136         0.009804        230.950000
# 1     ART0000809  ART0005136         0.019608        561.350000
# 2     ART0001066  ART0003099        56.000000          0.001870
# 3     ART0001068  ART0004671        38.000000          0.036000
# 4     ART0001073  ART0002240        46.000000          0.086685
# ...          ...         ...              ...               ...
# 1074  ART0007130  ART0001228         1.000000          1.500000
# 1075  ART0007133  ART0005136         0.029412          0.000000
# 1076  ART0007141  ART0002191         1.000000          6.500000
# 1077  ART0007148  ART0002619         1.000000         30.000000
# 1078  ART0007166  ART0000877         1.000000         35.816667
#
#       QuantitydiOutput  ImportoCostoTOTALE
# 0                102.0              230.95
# 1                102.0             1122.70
# 2                 19.0                1.99
# 3                  5.0                6.84
# 4                  4.0               15.95
# ...                ...                 ...
# 1074              15.0               22.50
# 1075             102.0                0.00
# 1076               2.0               13.00
# 1077               2.0               60.00
# 1078               3.0              107.45
#
# [1079 rows x 6 columns]

# %%
print(consumiConsuntivoVolProd.shape, consumiConsuntivoUnitByMP.shape)
print(consumiBudgetVolProd.shape, consumiBudgetVolProd.shape)
# Out:
# (1079, 6) (2771, 5)
# (937, 6) (937, 6)

# %%
print(sqldf('select * from consumiConsuntivoVolProd where CostoPerUnitaMis is null').shape)
print(sqldf('select * from consumiBudgetVolProd where CostoPerUnitaMis is null').shape)
# TODO rimuovere la maggior parte di quanitity nulle possibile dalle lavorazioni continua a essere importante!
# Out:
# (0, 6)
# (0, 6)

# %%
print(sqldf('select sum(ImportoCostoTOTALE) from consumiConsuntivoUnitByMP'))
print(sqldf('select sum(ImpiegoPerPezzo*CostoPerUnitaMis*QuantitydiOutput) from consumiConsuntivoVolProd'))
print(sqldf('select sum(ImportoCostoTOTALE) from consumiBudgetUnitByMP'))
print(sqldf('select sum(ImpiegoPerPezzo*CostoPerUnitaMis*QuantitydiOutput) from consumiBudgetVolProd'))
# non si perdono dei decimali
# Out:
#    sum(ImportoCostoTOTALE)
# 0                 289639.5
#    sum(ImpiegoPerPezzo*CostoPerUnitaMis*QuantitydiOutput)
# 0                                          289033.53
#    sum(ImportoCostoTOTALE)
# 0                192906.47
#    sum(ImpiegoPerPezzo*CostoPerUnitaMis*QuantitydiOutput)
# 0                                          192204.42

# %% [markdown]
# ##### Scostamenti

# %%
#consumiConsuntivoVolProd.drop(columns='NrOrdineProduzione',inplace=True)
#consumiBudgetVolProd.drop(columns='NrOrdineProduzione',inplace=True)

# %%
ConsumiUnit = pd.merge(consumiConsuntivoVolProd,consumiBudgetVolProd, on = ['CodiceMP','NrArticolo'], how = 'outer')
ConsumiUnit
# Out:
#         CodiceMP  NrArticolo  ImpiegoPerPezzo_x  CostoPerUnitaMis_x  \
# 0     ART0000771  ART0005136           0.009804          230.950000
# 1     ART0000809  ART0005136           0.019608          561.350000
# 2     ART0001066  ART0003099          56.000000            0.001870
# 3     ART0001068  ART0004671          38.000000            0.036000
# 4     ART0001073  ART0002240          46.000000            0.086685
# ...          ...         ...                ...                 ...
# 1310  ART0005913  ART0002191                NaN                 NaN
# 1311  ART0005917  ART0001610                NaN                 NaN
# 1312  ART0005930  ART0000229                NaN                 NaN
# 1313  ART0005935  ART0004675                NaN                 NaN
# 1314  ART0005943  ART0001731                NaN                 NaN
#
#       QuantitydiOutput_x  ImportoCostoTOTALE_x  ImpiegoPerPezzo_y  \
# 0                  102.0                230.95                NaN
# 1                  102.0               1122.70                NaN
# 2                   19.0                  1.99                NaN
# 3                    5.0                  6.84                NaN
# 4                    4.0                 15.95                NaN
# ...                  ...                   ...                ...
# 1310                 NaN                   NaN               20.0
# 1311                 NaN                   NaN              243.0
# 1312                 NaN                   NaN              130.0
# 1313                 NaN                   NaN               45.0
# 1314                 NaN                   NaN                2.0
#
#       CostoPerUnitaMis_y  QuantitydiOutput_y  ImportoCostoTOTALE_y
# 0                    NaN                 NaN                   NaN
# 1                    NaN                 NaN                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    NaN                 NaN                   NaN
# ...                  ...                 ...                   ...
# 1310            0.339250                 2.0                 13.57
# 1311            0.000597                 4.0                  0.58
# 1312            0.005064                12.0                  7.90
# 1313            0.014311                 5.0                  3.22
# 1314            4.500000                10.0                 90.00
#
# [1315 rows x 10 columns]

# %%
BudgetEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_x) from ConsumiUnit').iloc[0][0]
ImpiegoEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_y) from ConsumiUnit').iloc[0][0]
ImpiegoStandardMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from ConsumiUnit').iloc[0][0]
BudgetStandardMP = sqldf('select sum(QuantitydiOutput_y*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from ConsumiUnit').iloc[0][0]

# %%
ScostamentoVolumeMP =  ImpiegoStandardMP - BudgetStandardMP
ScostamentoImpiegoMP = ImpiegoEffettivoMP-ImpiegoStandardMP
ScostamentoPrezzoMP = BudgetEffettivoMP-ImpiegoEffettivoMP

# %%
print(BudgetEffettivoMP)
print(ImpiegoEffettivoMP)
print(ImpiegoStandardMP)
print(BudgetStandardMP)
print(ScostamentoVolumeMP)
print(ScostamentoImpiegoMP)
print(ScostamentoPrezzoMP)
print(ScostamentoVolumeMP+ScostamentoImpiegoMP+ScostamentoPrezzoMP)
# Out:
# 289033.53000000014
# 272523.2279339363
# 189145.68359840667
# 192204.42
# -3058.7364015933417
# 83377.54433552962
# 16510.302066063858
# 96829.11000000013

# %% [markdown]
# # Socostamento di volume, mix e prezzo per i ricavi

# %% [markdown]
#  group by NrArticolo dei ricavi

# %%
venditeConsuntivoArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity, sum(TotaleEuro) as TotaleEuro
        from venditeConsuntivo
        group by NrArticolo''')
venditeConsuntivoArt
# Out:
#      NrArticolo  Quantity    TotaleEuro
# 0    ART0000018         2     91.720170
# 1    ART0000041         4    400.233470
# 2    ART0000042         4    600.350204
# 3    ART0000043         2    250.145918
# 4    ART0000115         3   1095.000000
# ..          ...       ...           ...
# 408  ART0005109         9    210.122572
# 409  ART0005110         9    435.253898
# 410  ART0005111         7    204.285833
# 411  ART0005112         7    262.653214
# 412  ART0005136      1676  10502.137768
#
# [413 rows x 3 columns]

# %%
venditeBudgetArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity, sum(TotaleEuro) as TotaleEuro
        from venditeBudget
        group by NrArticolo''')
venditeBudgetArt
# Out:
#      NrArticolo  Quantity    TotaleEuro
# 0    ART0000018         2     85.380894
# 1    ART0000041         4    360.497107
# 2    ART0000042         4    569.205958
# 3    ART0000043         2    218.195617
# 4    ART0000115        12   1965.000000
# ..          ...       ...           ...
# 408  ART0005109         4    106.251779
# 409  ART0005110         2     94.867660
# 410  ART0005111         2     66.407362
# 411  ART0005112         2     85.380894
# 412  ART0005136       630  12932.919149
#
# [413 rows x 3 columns]

# %% [markdown]
# ##### calcolo del delta dei volumi

# %%
vendite = pd.merge(venditeConsuntivoArt,venditeBudgetArt, on = ['NrArticolo'], how = 'outer')
vendite
# Out:
#      NrArticolo  Quantity_x  TotaleEuro_x  Quantity_y  TotaleEuro_y
# 0    ART0000018           2     91.720170           2     85.380894
# 1    ART0000041           4    400.233470           4    360.497107
# 2    ART0000042           4    600.350204           4    569.205958
# 3    ART0000043           2    250.145918           2    218.195617
# 4    ART0000115           3   1095.000000          12   1965.000000
# ..          ...         ...           ...         ...           ...
# 408  ART0005109           9    210.122572           4    106.251779
# 409  ART0005110           9    435.253898           2     94.867660
# 410  ART0005111           7    204.285833           2     66.407362
# 411  ART0005112           7    262.653214           2     85.380894
# 412  ART0005136        1676  10502.137768         630  12932.919149
#
# [413 rows x 5 columns]

# %%
sqldf('''select sum(TotaleEuro_x) from vendite''')
# Out:
#    sum(TotaleEuro_x)
# 0      507842.851413

# %%
sqldf('''select sum(TotaleEuro_y) from vendite''')
# Out:
#    sum(TotaleEuro_y)
# 0      395335.892443

# %%
sqldf('''select NrArticolo, Quantity_x-Quantity_y as DiffQuantity
        from vendite
        order by DiffQuantity desc
        ''')
# Out:
#      NrArticolo  DiffQuantity
# 0    ART0005136          1046
# 1    ART0000748           291
# 2    ART0001575           200
# 3    ART0004397           114
# 4    ART0000229           113
# ..          ...           ...
# 408  ART0001628           -96
# 409  ART0004363          -114
# 410  ART0001154          -176
# 411  ART0003610          -176
# 412  ART0003780          -320
#
# [413 rows x 2 columns]

# %%
sqldf('''select sum(Quantity_x-Quantity_y) as DiffQuantity
        from vendite
        ''')
# Out:
#    DiffQuantity
# 0          2105

# %% [markdown]
# ##### creazione colonne mix, volume, prezzo unitario

# %%
venditeBudgetS = sqldf('''select NrArticolo, (Quantity*100000000000/7224) as Mix, 7224 as VolumeTotale, TotaleEuro/Quantity as PrezzoUnitario
        from venditeBudgetArt''')
venditeBudgetS
# Out:
#      NrArticolo         Mix  VolumeTotale  PrezzoUnitario
# 0    ART0000018    27685492          7224       42.690447
# 1    ART0000041    55370985          7224       90.124277
# 2    ART0000042    55370985          7224      142.301489
# 3    ART0000043    27685492          7224      109.097809
# 4    ART0000115   166112956          7224      163.750000
# ..          ...         ...           ...             ...
# 408  ART0005109    55370985          7224       26.562945
# 409  ART0005110    27685492          7224       47.433830
# 410  ART0005111    27685492          7224       33.203681
# 411  ART0005112    27685492          7224       42.690447
# 412  ART0005136  8720930232          7224       20.528443
#
# [413 rows x 4 columns]

# %%
sqldf('select sum(Mix*VolumeTotale*PrezzoUnitario)/100000000000 from venditeBudgetS')
# Out:
#    sum(Mix*VolumeTotale*PrezzoUnitario)/100000000000
# 0                                      395335.890784

# %%
sqldf('select sum(Quantity) from venditeConsuntivo')
# Out:
#    sum(Quantity)
# 0           9329

# %%
venditeConsuntivoS = sqldf('''select NrArticolo, (Quantity*100000000000/9329) as Mix, 9329 as VolumeTotale, TotaleEuro/Quantity as PrezzoUnitario
        from venditeConsuntivoArt''')
venditeConsuntivoS
# Out:
#      NrArticolo          Mix  VolumeTotale  PrezzoUnitario
# 0    ART0000018     21438525          9329       45.860085
# 1    ART0000041     42877050          9329      100.058367
# 2    ART0000042     42877050          9329      150.087551
# 3    ART0000043     21438525          9329      125.072959
# 4    ART0000115     32157787          9329      365.000000
# ..          ...          ...           ...             ...
# 408  ART0005109     96473362          9329       23.346952
# 409  ART0005110     96473362          9329       48.361544
# 410  ART0005111     75034837          9329       29.183690
# 411  ART0005112     75034837          9329       37.521888
# 412  ART0005136  17965483974          9329        6.266192
#
# [413 rows x 4 columns]

# %%
sqldf('select sum(Mix*VolumeTotale*PrezzoUnitario)/100000000000 from venditeConsuntivoS')
# Out:
#    sum(Mix*VolumeTotale*PrezzoUnitario)/100000000000
# 0                                      507842.849547

# %% [markdown]
# ### Calcolo socostamenti di volume, mix e prezzo

# %%
venditeS = pd.merge(venditeConsuntivoS, venditeBudgetS, on = ['NrArticolo'], how = 'outer')
venditeS
# Out:
#      NrArticolo        Mix_x  VolumeTotale_x  PrezzoUnitario_x       Mix_y  \
# 0    ART0000018     21438525            9329         45.860085    27685492
# 1    ART0000041     42877050            9329        100.058367    55370985
# 2    ART0000042     42877050            9329        150.087551    55370985
# 3    ART0000043     21438525            9329        125.072959    27685492
# 4    ART0000115     32157787            9329        365.000000   166112956
# ..          ...          ...             ...               ...         ...
# 408  ART0005109     96473362            9329         23.346952    55370985
# 409  ART0005110     96473362            9329         48.361544    27685492
# 410  ART0005111     75034837            9329         29.183690    27685492
# 411  ART0005112     75034837            9329         37.521888    27685492
# 412  ART0005136  17965483974            9329          6.266192  8720930232
#
#      VolumeTotale_y  PrezzoUnitario_y
# 0              7224         42.690447
# 1              7224         90.124277
# 2              7224        142.301489
# 3              7224        109.097809
# 4              7224        163.750000
# ..              ...               ...
# 408            7224         26.562945
# 409            7224         47.433830
# 410            7224         33.203681
# 411            7224         42.690447
# 412            7224         20.528443
#
# [413 rows x 7 columns]

# %%
sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x)/100000000000 from venditeS')
# Out:
#    sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x)/100000000000
# 0                                      507842.849547

# %%
z = sqldf('select NrArticolo,(Mix_y*VolumeTotale_y*PrezzoUnitario_y)/100000000000 as c from venditeS ')
z
# Out:
#      NrArticolo             c
# 0    ART0000018     85.380891
# 1    ART0000041    360.497103
# 2    ART0000042    569.205951
# 3    ART0000043    218.195611
# 4    ART0000115   1964.999990
# ..          ...           ...
# 408  ART0005109    106.251778
# 409  ART0005110     94.867657
# 410  ART0005111     66.407360
# 411  ART0005112     85.380891
# 412  ART0005136  12932.919148
#
# [413 rows x 2 columns]

# %%
BudgetStandardRic = sqldf('select sum(Mix_y*VolumeTotale_y*PrezzoUnitario_y)/100000000000 from venditeS ').iloc[0][0]
MixStandardRic = sqldf('select sum(Mix_y*VolumeTotale_x*PrezzoUnitario_y)/100000000000 from venditeS ').iloc[0][0]
MixEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_y)/100000000000 from venditeS ').iloc[0][0]
BudgetEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x)/100000000000 from venditeS ').iloc[0][0]

# %%
print(BudgetStandardRic)
print(MixStandardRic)
print(MixEffettivoRic)
print(BudgetEffettivoRic)
# Out:
# 395335.8907839928
# 510532.7415730725
# 539112.4259562771
# 507842.84954721347

# %%
ScostamentoVolumeRic = MixStandardRic-BudgetStandardRic
ScostamentoMixRic = MixEffettivoRic-MixStandardRic
ScostamentoPrezzoRic = BudgetEffettivoRic-MixEffettivoRic

# %%
print(ScostamentoVolumeRic)
print(ScostamentoMixRic)
print(ScostamentoPrezzoRic)
print(ScostamentoVolumeRic+ScostamentoMixRic+ScostamentoPrezzoRic)
# Out:
# 115196.85078907968
# 28579.684383204556
# -31269.576409063593
# 112506.95876322064

# %% [markdown]
# # Vista globale degli scostamenti

# %%
data = {'Index': ['Ricavi', 'CostiMP', 'CostiLav', 'Margine'], 
        'Budget' : [BudgetStandardRic, BudgetStandardMP,BudgetStandardLav, (BudgetStandardRic - (BudgetStandardMP+BudgetStandardLav))],
        'ScostamentoVolume' : [ScostamentoVolumeRic,ScostamentoVolumeMP,ScostamentoVolumeLav, (ScostamentoVolumeRic - (ScostamentoVolumeMP+ScostamentoVolumeLav))], 
        'MixStandard' : [MixStandardRic, ImpiegoStandardMP,ImpiegoStandardLav, (MixStandardRic - (ImpiegoStandardMP+ImpiegoStandardLav))],
        'ScostamentoMix' : [ScostamentoMixRic,ScostamentoImpiegoMP,ScostamentoImpiegoLav, (ScostamentoMixRic - (ScostamentoImpiegoMP+ScostamentoImpiegoLav))],
        'MixEffettivo' : [MixEffettivoRic, ImpiegoEffettivoMP,ImpiegoEffettivoLav, (MixEffettivoRic - (ImpiegoEffettivoMP+ImpiegoEffettivoLav))],
        'ScostamentoPrezzo' : [ScostamentoPrezzoRic,ScostamentoPrezzoMP,ScostamentoPrezzoLav, (ScostamentoPrezzoRic - (ScostamentoPrezzoMP+ScostamentoPrezzoLav))], 
        'Consuntivo' : [BudgetEffettivoRic, BudgetEffettivoMP, BudgetEffettivoLav, (BudgetEffettivoRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
        'ScostamentoTotale' : [BudgetEffettivoRic-BudgetStandardRic,BudgetEffettivoMP-BudgetStandardMP,BudgetEffettivoLav-BudgetStandardLav, (BudgetEffettivoRic - BudgetStandardRic - (BudgetEffettivoMP-BudgetStandardMP+BudgetEffettivoLav-BudgetStandardLav))]}

# %%
pd.DataFrame(data)
# Out:
#       Index         Budget  ScostamentoVolume    MixStandard  ScostamentoMix  \
# 0    Ricavi  395335.890784      115196.850789  510532.741573    28579.684383
# 1   CostiMP  192204.420000       -3058.736402  189145.683598    83377.544336
# 2  CostiLav  192493.776242       57586.739818  250080.516059    31209.399594
# 3   Margine   10637.694542       60668.847373   71306.541915   -86007.259546
#
#     MixEffettivo  ScostamentoPrezzo     Consuntivo  ScostamentoTotale
# 0  539112.425956      -31269.576409  507842.849547      112506.958763
# 1  272523.227934       16510.302066  289033.530000       96829.110000
# 2  281289.915653       77445.140220  358735.055873      166241.279631
# 3  -14700.717631     -125225.018695 -139925.736326     -150563.430868

# %%
print(-119959.519152+96308.420839-125320.243955)
# Out:
# -148971.342268

# %% [markdown]
# # Repeat ma tenendo conto della valuta

# %%
venditeConsuntivoArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity,  sum(ImportoVenditaValutaLocaleTOTALEVENDITA) as TotaleLocale, Valuta, TassoCambioMedio
        from venditeConsuntivo
        group by NrArticolo, Valuta, TassoCambioMedio''')
venditeBudgetArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity, sum(ImportoVenditaValutaLocaleTOTALEVENDITA) as TotaleLocale, Valuta, TassoCambioMedio
        from venditeBudget
        group by NrArticolo, Valuta, TassoCambioMedio ''')

# %%
venditeBudgetArt
# Out:
#      NrArticolo  Quantity  TotaleLocale  Valuta TassoCambioMedio
# 0    ART0000018         2         90.00       2           1.0541
# 1    ART0000041         4        380.00       2           1.0541
# 2    ART0000042         4        600.00       2           1.0541
# 3    ART0000043         2        230.00       2           1.0541
# 4    ART0000115        12       1965.00       1                1
# ..          ...       ...           ...     ...              ...
# 410  ART0005111         2         70.00       2           1.0541
# 411  ART0005112         2         90.00       2           1.0541
# 412  ART0005136        87       8933.00       1                1
# 413  ART0005136        80       4175.21       2           1.0541
# 414  ART0005136       463       4812.00       3            123.4
#
# [415 rows x 5 columns]

# %% [markdown]
# ##### creazione colonne mix, volume, prezzo unitario (locale)

# %%
venditeConsuntivoS = sqldf('''select NrArticolo, (Quantity*100000000000/9329) as Mix, 9329 as VolumeTotale, TotaleLocale/Quantity as PrezzoUnitario, Valuta, TassoCambioMedio, (TotaleLocale/Quantity)/TassoCambioMedio as PrezzoUnitarioEuro
        from venditeConsuntivoArt''')
venditeBudgetS = sqldf('''select NrArticolo, (Quantity*100000000000/7224) as Mix, 7224 as VolumeTotale, TotaleLocale/Quantity as PrezzoUnitario, Valuta, TassoCambioMedio, (TotaleLocale/Quantity)/TassoCambioMedio as PrezzoUnitarioEuro
        from venditeBudgetArt''')

# %% [markdown]
# ### Calcolo socostamenti di volume, mix, prezzo e valuta

# %%
venditeS1 = pd.merge(venditeConsuntivoS, venditeBudgetS, on = ['NrArticolo', 'Valuta'], how = 'outer')
venditeS1
#venditeS1.to_excel('venditeS1.xlsx')
# Out:
#      NrArticolo        Mix_x  VolumeTotale_x  PrezzoUnitario_x  Valuta  \
# 0    ART0000018     21438525            9329         55.000000       2
# 1    ART0000041     42877050            9329        120.000000       2
# 2    ART0000042     42877050            9329        180.000000       2
# 3    ART0000043     21438525            9329        150.000000       2
# 4    ART0000115     32157787            9329        365.000000       1
# ..          ...          ...             ...               ...     ...
# 410  ART0005111     75034837            9329         35.000000       2
# 411  ART0005112     75034837            9329         45.000000       2
# 412  ART0005136    686032800            9329         39.109375       1
# 413  ART0005136    439489763            9329        229.121951       2
# 414  ART0005136  16839961410            9329         14.286073       3
#
#     TassoCambioMedio_x  PrezzoUnitarioEuro_x       Mix_y  VolumeTotale_y  \
# 0               1.1993             45.860085    27685492            7224
# 1               1.1993            100.058367    55370985            7224
# 2               1.1993            150.087551    55370985            7224
# 3               1.1993            125.072959    27685492            7224
# 4                    1            365.000000   166112956            7224
# ..                 ...                   ...         ...             ...
# 410             1.1993             29.183690    27685492            7224
# 411             1.1993             37.521888    27685492            7224
# 412                  1             39.109375  1204318936            7224
# 413             1.1993            191.046403  1107419712            7224
# 414             135.01              0.105815  6409191583            7224
#
#      PrezzoUnitario_y TassoCambioMedio_y  PrezzoUnitarioEuro_y
# 0           45.000000             1.0541             42.690447
# 1           95.000000             1.0541             90.124277
# 2          150.000000             1.0541            142.301489
# 3          115.000000             1.0541            109.097809
# 4          163.750000                  1            163.750000
# ..                ...                ...                   ...
# 410         35.000000             1.0541             33.203681
# 411         45.000000             1.0541             42.690447
# 412        102.678161                  1            102.678161
# 413         52.190125             1.0541             49.511550
# 414         10.393089              123.4              0.084223
#
# [415 rows x 12 columns]

# %%
BudgetStandardRic = sqldf('select sum(Mix_y*VolumeTotale_y*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
MixStandardRic = sqldf('select sum(Mix_y*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
MixEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
BudgetEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
BudgetEffettivoValutaRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_x)/100000000000 from venditeS1 ').iloc[0][0]

# %%
print(BudgetStandardRic)
print(MixStandardRic)
print(MixEffettivoRic)
print(BudgetEffettivoRic)
print(BudgetEffettivoValutaRic)
# Out:
# 395335.8907780576
# 510532.74156540784
# 513440.445133813
# 569389.7443994995
# 507842.8495423171

# %%
ScostamentoVolumeRic = MixStandardRic-BudgetStandardRic
ScostamentoMixRic = MixEffettivoRic-MixStandardRic
ScostamentoPrezzoRic = BudgetEffettivoRic-MixEffettivoRic
ScostamentoValutaRic = BudgetEffettivoValutaRic-BudgetEffettivoRic

# %%
print(ScostamentoVolumeRic)
print(ScostamentoMixRic)
print(ScostamentoPrezzoRic)
print(ScostamentoValutaRic)
print(ScostamentoVolumeRic+ScostamentoMixRic+ScostamentoPrezzoRic+ScostamentoValutaRic)
# Out:
# 115196.85078735021
# 2907.7035684051807
# 55949.29926568648
# -61546.8948571824
# 112506.95876425947

# %% [markdown]
# # Vista globale degli scostamenti v2

# %%
data = {'Index': ['Ricavi', 'CostiMP', 'CostiLav', 'Margine'], 
        'Budget' : [BudgetStandardRic, BudgetStandardMP,BudgetStandardLav, (BudgetStandardRic - (BudgetStandardMP+BudgetStandardLav))],
        'ScostamentoVolume' : [ScostamentoVolumeRic,ScostamentoVolumeMP,ScostamentoVolumeLav, (ScostamentoVolumeRic - (ScostamentoVolumeMP+ScostamentoVolumeLav))], 
        'MixStandard' : [MixStandardRic, ImpiegoStandardMP,ImpiegoStandardLav, (MixStandardRic - (ImpiegoStandardMP+ImpiegoStandardLav))],
        'ScostamentoMix' : [ScostamentoMixRic,ScostamentoImpiegoMP,ScostamentoImpiegoLav, (ScostamentoMixRic - (ScostamentoImpiegoMP+ScostamentoImpiegoLav))],
        'MixEffettivo' : [MixEffettivoRic, ImpiegoEffettivoMP,ImpiegoEffettivoLav, (MixEffettivoRic - (ImpiegoEffettivoMP+ImpiegoEffettivoLav))],
        'ScostamentoPrezzo' : [ScostamentoPrezzoRic,ScostamentoPrezzoMP,ScostamentoPrezzoLav, (ScostamentoPrezzoRic - (ScostamentoPrezzoMP+ScostamentoPrezzoLav))], 
        'MixValuta' : [BudgetEffettivoRic, BudgetEffettivoMP,BudgetEffettivoLav, (BudgetEffettivoRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
        'ScostamentoValuta' : [ScostamentoValutaRic, 0, 0, (ScostamentoValutaRic - (0+0))],
        'Consuntivo' : [BudgetEffettivoValutaRic, BudgetEffettivoMP, BudgetEffettivoLav, (BudgetEffettivoValutaRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
        'ScostamentoTotale' : [BudgetEffettivoValutaRic-BudgetStandardRic,BudgetEffettivoMP-BudgetStandardMP,BudgetEffettivoLav-BudgetStandardLav, (BudgetEffettivoValutaRic - BudgetStandardRic - (BudgetEffettivoMP-BudgetStandardMP+BudgetEffettivoLav-BudgetStandardLav))]}

# %%
pd.DataFrame(data)
# Out:
#       Index         Budget  ScostamentoVolume    MixStandard  ScostamentoMix  \
# 0    Ricavi  395335.890778      115196.850787  510532.741565     2907.703568
# 1   CostiMP  192204.420000       -3058.736402  189145.683598    83377.544336
# 2  CostiLav  192493.776242       57586.739818  250080.516059    31209.399594
# 3   Margine   10637.694536       60668.847371   71306.541908  -111679.240361
#
#     MixEffettivo  ScostamentoPrezzo      MixValuta  ScostamentoValuta  \
# 0  513440.445134       55949.299266  569389.744399      -61546.894857
# 1  272523.227934       16510.302066  289033.530000           0.000000
# 2  281289.915653       77445.140220  358735.055873           0.000000
# 3  -40372.698453      -38006.143020  -78378.841473      -61546.894857
#
#       Consuntivo  ScostamentoTotale
# 0  507842.849542      112506.958764
# 1  289033.530000       96829.110000
# 2  358735.055873      166241.279631
# 3 -139925.736331     -150563.430867

# %%
60668.847371-111679.240361-38006.143020-61546.894857
# Out:
# -150563.43086700002

# %% [markdown]
# come vedremo, i volumi di vendita non coincidono ai volumi di produzione, come negli esercizi fatti a lezione.
#
# Invece, a budget, si vendenono circa 412 prodotti diversi, mentre si lavorano circa 503, dei quali soltanto 73 passano per una fase di montaggio nell'anno in quesitone.
#
# Questo ci porta alla conclusione che ci sono delle rimanenze, e non tutto cio che e prodotto nell'anno e venduto nello stesso anno.

# %%
impiegoBudgetNew
# Out:
#       NrArticolo budgetConsuntivo           Descrizione NrAreaProduzione  \
# 0     ART0000018           BUDGET     Controllo qualità               CQ
# 1     ART0000018           BUDGET             Fresatura              A30
# 2     ART0000018           BUDGET             Tornitura              A20
# 3     ART0000041           BUDGET     Controllo qualità               CQ
# 4     ART0000041           BUDGET             Fresatura              A30
# ...          ...              ...                   ...              ...
# 1222  ART0005136           BUDGET  Foratura/Maschiatura              A32
# 1223  ART0005136           BUDGET             Fresatura              A30
# 1224  ART0005136           BUDGET             Montaggio              A40
# 1225  ART0005136           BUDGET       Taglio spezzoni              A20
# 1226  ART0005136           BUDGET             Tornitura              A20
#
#       TempoRisorsa  CostoOrario  QuantitydiOutput
# 0             0.00    12.750000               2.0
# 1             0.75    51.000000               2.0
# 2             1.00    68.000000               2.0
# 3             0.00    12.750000               4.0
# 4             1.25    51.000000               4.0
# ...            ...          ...               ...
# 1222          3.00    42.500000               0.0
# 1223         21.33    47.600000               4.0
# 1224          8.25    42.500000               0.0
# 1225          4.50    68.000000              29.0
# 1226         53.75    65.166667              51.0
#
# [1227 rows x 7 columns]

# %%
sqldf('select NrArticolo, QuantitydiOutput from impiegoBudgetNew group by NrArticolo,QuantitydiOutput order by NrArticolo')
# Out:
#      NrArticolo  QuantitydiOutput
# 0    ART0000018               2.0
# 1    ART0000041               4.0
# 2    ART0000042               4.0
# 3    ART0000043               2.0
# 4    ART0000115               3.0
# ..          ...               ...
# 560  ART0005136               4.0
# 561  ART0005136              29.0
# 562  ART0005136              32.0
# 563  ART0005136              50.0
# 564  ART0005136              51.0
#
# [565 rows x 2 columns]

# %%
sqldf('select NrArticolo,Quantity from venditeBudget group by NrArticolo,Quantity order by NrArticolo')
# Out:
#      NrArticolo  Quantity
# 0    ART0000018         2
# 1    ART0000041         4
# 2    ART0000042         4
# 3    ART0000043         2
# 4    ART0000115         1
# ..          ...       ...
# 585  ART0005136        30
# 586  ART0005136        32
# 587  ART0005136        42
# 588  ART0005136        50
# 589  ART0005136        64
#
# [590 rows x 2 columns]

# %%
sqldf('select NrArticolo,sum(Quantity) as quantita from venditeBudget group by NrArticolo order by NrArticolo')
# Out:
#      NrArticolo  quantita
# 0    ART0000018         2
# 1    ART0000041         4
# 2    ART0000042         4
# 3    ART0000043         2
# 4    ART0000115        12
# ..          ...       ...
# 408  ART0005109         4
# 409  ART0005110         2
# 410  ART0005111         2
# 411  ART0005112         2
# 412  ART0005136       630
#
# [413 rows x 2 columns]

# %%
sqldf("SELECT DISTINCT NrArticolo FROM dfImpiegoRisorse WHERE (budgetConsuntivo = 'BUDGET' or budgetConsuntivo = 'Budget')")
# Out:
#      NrArticolo
# 0    ART0000018
# 1    ART0000041
# 2    ART0000042
# 3    ART0000043
# 4    ART0000115
# ..          ...
# 499  ART0005109
# 500  ART0005110
# 501  ART0005111
# 502  ART0005112
# 503  ART0005136
#
# [504 rows x 1 columns]

# %%
sqldf("SELECT DISTINCT NrArticolo,QuantitydiOutput FROM dfImpiegoRisorse WHERE (budgetConsuntivo = 'BUDGET' or budgetConsuntivo = 'Budget') and Descrizione = 'Montaggio'")
# Out:
#     NrArticolo  QuantitydiOutput
# 0   ART0000748              50.0
# 1   ART0000748              10.0
# 2   ART0000748              30.0
# 3   ART0000752               1.0
# 4   ART0000752               6.0
# ..         ...               ...
# 69  ART0004099               1.0
# 70  ART0004104               4.0
# 71  ART0004146              31.0
# 72  ART0004146               0.0
# 73  ART0005136               0.0
#
# [74 rows x 2 columns]

# %%
pd.merge(
    sqldf('select NrArticolo,sum(Quantity) as quantita from venditeBudget group by NrArticolo order by NrArticolo'),
    sqldf("SELECT DISTINCT NrArticolo,QuantitydiOutput FROM dfImpiegoRisorse WHERE (budgetConsuntivo = 'BUDGET' or budgetConsuntivo = 'Budget') and Descrizione = 'Montaggio'"), 
    on='NrArticolo', how='outer')
# Out:
#      NrArticolo  quantita  QuantitydiOutput
# 0    ART0000018         2               NaN
# 1    ART0000041         4               NaN
# 2    ART0000042         4               NaN
# 3    ART0000043         2               NaN
# 4    ART0000115        12               NaN
# ..          ...       ...               ...
# 439  ART0005109         4               NaN
# 440  ART0005110         2               NaN
# 441  ART0005111         2               NaN
# 442  ART0005112         2               NaN
# 443  ART0005136       630               0.0
#
# [444 rows x 3 columns]

# %%
venditeConsuntivo.to_excel('venditeConsuntivo.xlsx')

# %% [markdown]
# # By Criterion

# %% [markdown]
# ## By client

# %%
def by_client(dfVendite, client):
        dfVendite.rename(columns = {'budget/cons':'budget'}, inplace = True)
        venditeConsuntivo = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'CONSUNTIVO' or budget = 'Consuntivo'")
        venditeBudget = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'BUDGET' or budget = 'Budget'")

        venditeConsuntivo = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
        FROM venditeConsuntivo as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
        where k.Anno = 'Consuntivo' or k.Anno = 'CONSUNTIVO'
        ''')

        venditeBudget = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
        FROM venditeBudget as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
        where k.Anno = 'Budget' or k.Anno = 'BUDGET'
        ''')

        venditeConsuntivo = sqldf('select * from venditeConsuntivo where NrOrigine = "'+client+'"')

        venditeBudget = sqldf('select * from venditeBudget where NrOrigine = "'+client+'"')

        venditeConsuntivoArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity,  sum(ImportoVenditaValutaLocaleTOTALEVENDITA) as TotaleLocale, Valuta, TassoCambioMedio
                from venditeConsuntivo
                group by NrArticolo, Valuta, TassoCambioMedio''')
        venditeBudgetArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity, sum(ImportoVenditaValutaLocaleTOTALEVENDITA) as TotaleLocale, Valuta, TassoCambioMedio
                from venditeBudget
                group by NrArticolo, Valuta, TassoCambioMedio ''')

        venditeConsuntivoS = sqldf('''select NrArticolo, (Quantity*100000000000/9329) as Mix, 9329 as VolumeTotale, TotaleLocale/Quantity as PrezzoUnitario, Valuta, TassoCambioMedio, (TotaleLocale/Quantity)/TassoCambioMedio as PrezzoUnitarioEuro
                from venditeConsuntivoArt''')
        venditeBudgetS = sqldf('''select NrArticolo, (Quantity*100000000000/7224) as Mix, 7224 as VolumeTotale, TotaleLocale/Quantity as PrezzoUnitario, Valuta, TassoCambioMedio, (TotaleLocale/Quantity)/TassoCambioMedio as PrezzoUnitarioEuro
                from venditeBudgetArt''')

        venditeS1 = pd.merge(venditeConsuntivoS, venditeBudgetS, on = ['NrArticolo', 'Valuta'], how = 'outer')
        venditeS1.fillna(0, inplace = True)
        venditeS1


        BudgetStandardRic = sqldf('select sum(Mix_y*VolumeTotale_y*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
        MixStandardRic = sqldf('select sum(Mix_y*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
        MixEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
        BudgetEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
        BudgetEffettivoValutaRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_x)/100000000000 from venditeS1 ').iloc[0][0]

        if(BudgetStandardRic is None):
           BudgetStandardRic = 0

        if(BudgetEffettivoValutaRic is None):
          BudgetEffettivoValutaRic = 0

        ScostamentoVolumeRic = MixStandardRic-BudgetStandardRic
        ScostamentoMixRic = MixEffettivoRic-MixStandardRic
        ScostamentoPrezzoRic = BudgetEffettivoRic-MixEffettivoRic
        ScostamentoValutaRic = BudgetEffettivoValutaRic-BudgetEffettivoRic

        dicResult = {
        'BudgetStandardRic':BudgetStandardRic,
        'MixStandardRic':MixStandardRic,
        'MixEffettivoRic':MixEffettivoRic,
        'BudgetEffettivoRic':BudgetEffettivoRic,
        'BudgetEffettivoValutaRic':BudgetEffettivoValutaRic,
        'ScostamentoVolumeRic':ScostamentoVolumeRic,
        'ScostamentoMixRic':ScostamentoMixRic,
        'ScostamentoPrezzoRic':ScostamentoPrezzoRic,
        'ScostamentoValutaRic':ScostamentoValutaRic,
        'ScostamentoTotaleRic' : ScostamentoVolumeRic+ScostamentoMixRic+ScostamentoPrezzoRic+ScostamentoValutaRic
        }

        return dicResult

# %%
e = by_client(dfVendite, 'C00471')
e
# Out:
# {'BudgetStandardRic': 14292.79945018925,
#  'MixStandardRic': 18457.57559119816,
#  'MixEffettivoRic': 37328.980168508795,
#  'BudgetEffettivoRic': 39465.894976324234,
#  'BudgetEffettivoValutaRic': 34687.734423866736,
#  'ScostamentoVolumeRic': 4164.7761410089115,
#  'ScostamentoMixRic': 18871.404577310634,
#  'ScostamentoPrezzoRic': 2136.9148078154394,
#  'ScostamentoValutaRic': -4778.160552457499,
#  'ScostamentoTotaleRic': 20394.934973677486}

# %%
def by_client(dfVendite,dfConsumi,impiegoConsuntivo1, impiegoBudget1, client):

       dfVendite.rename(columns = {'budget/cons':'budget'}, inplace = True)
       venditeConsuntivo = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'CONSUNTIVO' or budget = 'Consuntivo'")
       venditeBudget = sqldf("SELECT DISTINCT * FROM dfVendite WHERE budget = 'BUDGET' or budget = 'Budget'")

       venditeConsuntivo = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
       FROM venditeConsuntivo as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
       where k.Anno = 'Consuntivo' or k.Anno = 'CONSUNTIVO'
       ''')

       venditeBudget = sqldf('''SELECT DISTINCT v.NrMovimento, v.budget, v.NrArticolo, v.Quantity, v.ImportoVenditaValutaLocaleTOTALEVENDITA,k.TassoCambioMedio,v.ImportoVenditaValutaLocaleTOTALEVENDITA/k.TassoCambioMedio as TotaleEuro, v.NrOrigine, c.CodCondizioniPagam, c.FattCumulative, c.Valuta
       FROM venditeBudget as v join dfClienti as c on v.NrOrigine = c.Nr join dfCambio as k on c.Valuta = k.CodiceValuta
       where k.Anno = 'Budget' or k.Anno = 'BUDGET'
       ''')

       venditeConsuntivo = sqldf('select * from venditeConsuntivo where NrOrigine = "'+client+'"')

       venditeBudget = sqldf('select * from venditeBudget where NrOrigine = "'+client+'"')

       venditeConsuntivoArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity,  sum(ImportoVenditaValutaLocaleTOTALEVENDITA) as TotaleLocale, Valuta, TassoCambioMedio
       from venditeConsuntivo
       group by NrArticolo, Valuta, TassoCambioMedio''')
       venditeBudgetArt = sqldf('''select NrArticolo, sum(Quantity) as Quantity, sum(ImportoVenditaValutaLocaleTOTALEVENDITA) as TotaleLocale, Valuta, TassoCambioMedio
       from venditeBudget
       group by NrArticolo, Valuta, TassoCambioMedio ''')

       venditeConsuntivoS = sqldf('''select NrArticolo, (Quantity*100000000000/9329) as Mix, 9329 as VolumeTotale, TotaleLocale/Quantity as PrezzoUnitario, Valuta, TassoCambioMedio, (TotaleLocale/Quantity)/TassoCambioMedio as PrezzoUnitarioEuro
       from venditeConsuntivoArt''')
       venditeBudgetS = sqldf('''select NrArticolo, (Quantity*100000000000/7224) as Mix, 7224 as VolumeTotale, TotaleLocale/Quantity as PrezzoUnitario, Valuta, TassoCambioMedio, (TotaleLocale/Quantity)/TassoCambioMedio as PrezzoUnitarioEuro
       from venditeBudgetArt''')

       venditeS1 = pd.merge(venditeConsuntivoS, venditeBudgetS, on = ['NrArticolo', 'Valuta'], how = 'outer')
       venditeS1.fillna(0, inplace = True)
       venditeS1


       BudgetStandardRic = sqldf('select sum(Mix_y*VolumeTotale_y*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
       MixStandardRic = sqldf('select sum(Mix_y*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
       MixEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
       BudgetEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_y)/100000000000 from venditeS1 ').iloc[0][0]
       BudgetEffettivoValutaRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_x)/100000000000 from venditeS1 ').iloc[0][0]

       if(BudgetStandardRic is None):
         BudgetStandardRic = 0

       if(MixStandardRic is None):
               MixStandardRic = 0
       
       if(MixEffettivoRic is None):
               MixEffettivoRic = 0
       
       if(BudgetEffettivoRic is None):
               BudgetEffettivoRic = 0

       if(BudgetEffettivoValutaRic is None):
         BudgetEffettivoValutaRic = 0

       ScostamentoVolumeRic = MixStandardRic-BudgetStandardRic
       ScostamentoMixRic = MixEffettivoRic-MixStandardRic
       ScostamentoPrezzoRic = BudgetEffettivoRic-MixEffettivoRic
       ScostamentoValutaRic = BudgetEffettivoValutaRic-BudgetEffettivoRic

       

       # materia prima

       articoli = sqldf('select distinct NrArticolo from venditeS1')

       dfConsumi.rename(columns = {'Budget/cons':'budget'}, inplace = True)
       consumiConsuntivo = sqldf("SELECT DISTINCT * FROM dfConsumi WHERE budget = 'CONSUNTIVO' and NrArticolo in (select * from articoli)")
       consumiBudget = sqldf("SELECT DISTINCT * FROM dfConsumi WHERE budget = 'BUDGET' and NrArticolo in (select * from articoli)") 

       consumiConsuntivoUnit = sqldf('''select distinct NrMovimento, CodiceMP, NrArticolo, QuantityMPImpiegata, ImportoCostoTOTALE/QuantityMPImpiegata as CostoUnitario, ImportoCostoTOTALE 
       from consumiConsuntivo
       order by CodiceMP''')
       consumiBudgetUnit = sqldf('''select distinct NrMovimento, CodiceMP, NrArticolo, QuantityMPImpiegata, ImportoCostoTOTALE/QuantityMPImpiegata as CostoUnitario, ImportoCostoTOTALE 
       from consumiBudget
       order by CodiceMP''')

       consumiConsuntivoUnitByMP = sqldf('''select CodiceMP, NrArticolo,938999.16 as Volume, sum(QuantityMPImpiegata) as QuantityMPImpiegata,sum(ImportoCostoTOTALE)/sum(QuantityMPImpiegata) as CostoUnitario , sum(ImportoCostoTOTALE) as ImportoCostoTOTALE
       from consumiConsuntivoUnit      
       group by CodiceMP, NrArticolo''')
       consumiBudgetUnitByMP = sqldf('''select CodiceMP, NrArticolo,550834.0 as Volume, sum(QuantityMPImpiegata) as QuantityMPImpiegata,sum(ImportoCostoTOTALE)/sum(QuantityMPImpiegata) as CostoUnitario , sum(ImportoCostoTOTALE) as ImportoCostoTOTALE
       from consumiBudgetUnit      
       group by CodiceMP, NrArticolo''')

       conVol = sqldf('select CodiceMP, sum(QuantityMPImpiegata) as VolumeByMP from consumiConsuntivoUnitByMP group by CodiceMP')
       buVol = sqldf('select CodiceMP, sum(QuantityMPImpiegata) as VolumeByMP from consumiBudgetUnitByMP group by CodiceMP')

       consumiConsuntivoUnitByMP = sqldf('''select CodiceMP, NrArticolo, VolumeByMP, (QuantityMPImpiegata/VolumeByMP) as Impiego, CostoUnitario, ImportoCostoTOTALE
       from consumiConsuntivoUnitByMP natural join conVol ''')
       consumiBudgetUnitByMP = sqldf('''select CodiceMP, NrArticolo, VolumeByMP, (QuantityMPImpiegata/VolumeByMP) as Impiego, CostoUnitario, ImportoCostoTOTALE
       from consumiBudgetUnitByMP natural join buVol''')

       ConsumiUnit = pd.merge(consumiConsuntivoUnitByMP,consumiBudgetUnitByMP, on = ['CodiceMP','NrArticolo'], how = 'outer')

       BudgetEffettivoMP = sqldf('select sum(VolumeByMP_x*Impiego_x*CostoUnitario_x) from ConsumiUnit').iloc[0][0]
       ImpiegoEffettivoMP = sqldf('select sum(VolumeByMP_x*Impiego_x*CostoUnitario_y) from ConsumiUnit').iloc[0][0]
       ImpiegoStandardMP = sqldf('select sum(VolumeByMP_x*Impiego_y*CostoUnitario_y) from ConsumiUnit').iloc[0][0]
       BudgetStandardMP = sqldf('select sum(VolumeByMP_y*Impiego_y*CostoUnitario_y) from ConsumiUnit').iloc[0][0]
       ScostamentoVolumeMP =  ImpiegoStandardMP - BudgetStandardMP
       ScostamentoImpiegoMP = ImpiegoEffettivoMP-ImpiegoStandardMP
       ScostamentoPrezzoMP = BudgetEffettivoMP-ImpiegoEffettivoMP 

       # lavorazioni

       impiegoConsuntivoNew = sqldf(''' select NrArticolo, budgetConsuntivo, NrOrdineProduzione, Descrizione, NrAreaProduzione, Risorsa, TempoRisorsa, TempoRisorsa/QuantitydiOutput as ImpiegoUnitario, CostoOrario ,QuantitydiOutput
       from impiegoConsuntivo1
       where NrArticolo in (select * from articoli)''')
       impiegoConsuntivoNew.drop(['NrOrdineProduzione'], axis=1, inplace=True)

       impiegoConsuntivoNew = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, sum(TempoRisorsa) as TempoRisorsa, avg(CostoOrario) as CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
       from impiegoConsuntivoNew
       group by NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione
       ''')

       vol = sqldf('select NrArticolo, sum(QuantitydiOutput) as Volume from impiegoConsuntivoNew group by NrArticolo')

       impiegoConsuntivoNew = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, TempoRisorsa, (TempoRisorsa/Volume) as ImpiegoUnitario, CostoOrario, Volume ,QuantitydiOutput
       from impiegoConsuntivoNew natural join vol
       ''')

       impiegoBudgetNew = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, sum(TempoRisorsa) as TempoRisorsa, avg(CostoOrario) as CostoOrario, sum(QuantitydiOutput) as QuantitydiOutput
       from impiegoBudget1
       where NrArticolo in (select * from articoli)
       group by NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione
       ''')
       vol = sqldf('select NrArticolo, sum(QuantitydiOutput) as Volume from impiegoBudgetNew group by NrArticolo')

       impiegoBudgetNew = sqldf(''' select NrArticolo, budgetConsuntivo, Descrizione, NrAreaProduzione, TempoRisorsa, (TempoRisorsa/Volume) as ImpiegoUnitario, CostoOrario, Volume ,QuantitydiOutput
       from impiegoBudgetNew natural join vol
       ''')

       impiegoConsuntivoNew.drop(['budgetConsuntivo'], axis=1, inplace=True)
       impiegoBudgetNew.drop(['budgetConsuntivo'], axis=1, inplace=True)
       x = pd.merge(impiegoConsuntivoNew, impiegoBudgetNew, on=['NrArticolo', 'Descrizione', 'NrAreaProduzione'], how='outer')

       #Budget Standard
       BudgetStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y	) from x').iloc[0][0]
       # Impiego Standard (volume a consuntivo)
       ImpiegoStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_x	) from x').iloc[0][0]
       # Impiego Effettivo (volume e impiego a consuntivo)
       ImpiegoEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_y*QuantitydiOutput_x	) from x').iloc[0][0]
       # Budget Effettivo (tutto a consuntivo)
       BudgetEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x	) from x').iloc[0][0]

       ScostamentoVolumeLav = ImpiegoStandardLav-b
       ScostamentoImpiegoLav = ImpiegoEffettivoLav-ImpiegoStandardLav
       ScostamentoPrezzoLav = BudgetEffettivoLav-ImpiegoEffettivoLav

       data = {client: ['Ricavi', 'CostiMP', 'CostiLav', 'Margine'], 
       'Budget' : [BudgetStandardRic, BudgetStandardMP,BudgetStandardLav, (BudgetStandardRic - (BudgetStandardMP+BudgetStandardLav))],
       'ScostamentoVolume' : [ScostamentoVolumeRic,ScostamentoVolumeMP,ScostamentoVolumeLav, (ScostamentoVolumeRic - (ScostamentoVolumeMP+ScostamentoVolumeLav))], 
       'MixStandard' : [MixStandardRic, ImpiegoStandardMP,ImpiegoStandardLav, (MixStandardRic - (ImpiegoStandardMP+ImpiegoStandardLav))],
       'ScostamentoMix' : [ScostamentoMixRic,ScostamentoImpiegoMP,ScostamentoImpiegoLav, (ScostamentoMixRic - (ScostamentoImpiegoMP+ScostamentoImpiegoLav))],
       'MixEffettivo' : [MixEffettivoRic, ImpiegoEffettivoMP,ImpiegoEffettivoLav, (MixEffettivoRic - (ImpiegoEffettivoMP+ImpiegoEffettivoLav))],
       'ScostamentoPrezzo' : [ScostamentoPrezzoRic,ScostamentoPrezzoMP,ScostamentoPrezzoLav, (ScostamentoPrezzoRic - (ScostamentoPrezzoMP+ScostamentoPrezzoLav))], 
       'MixValuta' : [BudgetEffettivoRic, BudgetEffettivoMP,BudgetEffettivoLav, (BudgetEffettivoRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
       'ScostamentoValuta' : [ScostamentoValutaRic, 0, 0, (ScostamentoValutaRic - (0+0))],
       'Consuntivo' : [BudgetEffettivoValutaRic, BudgetEffettivoMP, BudgetEffettivoLav, (BudgetEffettivoValutaRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
       'ScostamentoTotale' : [BudgetEffettivoValutaRic-BudgetStandardRic,BudgetEffettivoMP-BudgetStandardMP,BudgetEffettivoLav-BudgetStandardLav, (BudgetEffettivoValutaRic - BudgetStandardRic - (BudgetEffettivoMP-BudgetStandardMP+BudgetEffettivoLav-BudgetStandardLav))]}

       data = pd.DataFrame(data)

       return data

# %%
clients = sqldf('select distinct Nr from dfClienti')
scos = []
count = 0

for client in clients.values:
   theclient = client[0]
   if (sqldf('select * from dfVendite where NrOrigine = "'+theclient+'"').empty):
      continue
   print(theclient)
   scos.append(by_client(dfVendite,dfConsumi,impiegoConsuntivo1, impiegoBudget1, theclient))
   count += 1
# Out:
# C00001
# C00003
# C00004
# C00015
# C00017
# C00018
# C00020
# C00026
# C00084
# C00094
# C00117
# C00127
# C00140
# C00158
# C00236
# C00297
# C00344
# C00353
# C00454
# C00455
# C00456
# C00458
# C00461
# C00465
# C00471
# C00473
# C00474
# C00478
# C00479
# C00483
# C00487
# C00489
# C00492
# C00493
# C00498
# C00499
# C00504

# %%
def Func(x):
  return x.iloc[3,10]

scos.sort(key=Func)

# %%
scos[0]
# Out:
#      C00140         Budget  ScostamentoVolume    MixStandard  ScostamentoMix  \
# 0    Ricavi  339345.250517       98881.748663  438226.999179   -31816.279916
# 1   CostiMP  148088.440000       74185.889444  222274.329444     -531.712890
# 2  CostiLav   29394.642724     -146280.032028   46213.744214    -4492.997472
# 3   Margine  161862.167793      170975.891246  169738.925522   -26791.569554
#
#     MixEffettivo  ScostamentoPrezzo      MixValuta  ScostamentoValuta  \
# 0  406410.719263       50383.994864  456794.714128      -55304.421322
# 1  221742.616554        2248.293446  223990.910000           0.000000
# 2   41720.746742        7645.537867   49366.284609           0.000000
# 3  142947.355967       40490.163552  183437.519519      -55304.421322
#
#       Consuntivo  ScostamentoTotale
# 0  401490.292806       62145.042289
# 1  223990.910000       75902.470000
# 2   49366.284609       19971.641884
# 3  128133.098197      -33729.069596

# %% [markdown]
# ## By NrArticolo

# %%
def by_articolo(mergeImpiego, articolo):
    lavorazioniSingoloProdotto = sqldf('select * from x where NrArticolo = "'+articolo+'"')

    #Budget Standard
    BudgetStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y) from lavorazioniSingoloProdotto').iloc[0][0]
    # Impiego Standard (volume a consuntivo)
    ImpiegoStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]
    # Impiego Effettivo (volume e impiego a consuntivo)
    ImpiegoEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_y*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]
    # Budget Effettivo (tutto a consuntivo)
    BudgetEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]

    if(BudgetStandardLav is None):
                BudgetStandardLav = 0

    if(ImpiegoStandardLav is None):
                ImpiegoStandardLav = 0

    if(ImpiegoEffettivoLav is None):
                ImpiegoEffettivoLav = 0

    if(BudgetEffettivoLav is None):
                BudgetEffettivoLav = 0

    #Scostamenti
    ScostamentoVolumeLav = ImpiegoStandardLav-BudgetStandardLav
    ScostamentoImpiegoLav = ImpiegoEffettivoLav-ImpiegoStandardLav
    ScostamentoPrezzoLav = BudgetEffettivoLav-ImpiegoEffettivoLav

    data = {articolo: ['CostiLav'], 
            'Budget' : [BudgetStandardLav],
            'ScostamentoVolume' : [ScostamentoVolumeLav,], 
            'MixStandard' : [ImpiegoStandardLav],
            'ScostamentoMix' : [ScostamentoImpiegoLav],
            'MixEffettivo' : [ImpiegoEffettivoLav],
            'ScostamentoPrezzo' : [ScostamentoPrezzoLav], 
            'MixValuta' : [BudgetEffettivoLav],
            'ScostamentoValuta' : [0],
            'Consuntivo' : [BudgetEffettivoLav],
            'ScostamentoTotale' : [BudgetEffettivoLav-BudgetStandardLav]}

    return pd.DataFrame(data)

# %%
articoli = sqldf('select distinct NrArticolo from dfImpiegoRisorse')
scos = []

for articolo in articoli.values:
   theArticolo = articolo[0]
   print(theArticolo)
   scos.append(by_articolo(x, theArticolo))
# Out:
# ART0000018
# ART0000041
# ART0000042
# ART0000043
# ART0000115
# ART0000116
# ART0000119
# ART0000121
# ART0000125
# ART0000128
# ART0000129
# ART0004385
# ART0004386
# ART0004392
# ART0004397
# ART0004403
# ART0004410
# ART0004420
# ART0004440
# ART0004656
# ART0004659
# ART0004660
# ART0004671
# ART0004675
# ART0004689
# ART0004697
# ART0004711
# ART0004717
# ART0004718
# ART0004724
# ART0004725
# ART0004726
# ART0004727
# ART0004737
# ART0004836
# ART0004880
# ART0004885
# ART0004886
# ART0004889
# ART0004898
# ART0004901
# ART0004902
# ART0004904
# ART0004919
# ART0004924
# ART0004941
# ART0004942
# ART0004944
# ART0004946
# ART0004947
# ART0005011
# ART0005026
# ART0005028
# ART0005029
# ART0005030
# ART0005034
# ART0005035
# ART0005036
# ART0005037
# ART0005091
# ART0005109
# ART0005110
# ART0005111
# ART0005112
# ART0005136

# %%
def Func(x):
  return x.iloc[0,10]

scos.sort(key=Func)
scos

# %% [markdown]
# ## By articolo full stack!

# %%
def by_articolo_full(venditeS1, mergeImpiego, ConsumiUnit, articolo):

        venditeSingoloArticolo = sqldf('select * from venditeS1 where NrArticolo = "'+articolo+'"')

        BudgetStandardRic = sqldf('select sum(Mix_y*VolumeTotale_y*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
        MixStandardRic = sqldf('select sum(Mix_y*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
        MixEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
        BudgetEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
        BudgetEffettivoValutaRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_x)/100000000000 from venditeSingoloArticolo ').iloc[0][0]

        if(BudgetStandardRic is None):
                BudgetStandardRic = 0

        if(MixStandardRic is None):
                MixStandardRic = 0

        if(MixEffettivoRic is None):
                MixEffettivoRic = 0

        if(BudgetEffettivoRic is None):
                BudgetEffettivoRic = 0

        if(BudgetEffettivoValutaRic is None):
                BudgetEffettivoValutaRic = 0

        ScostamentoVolumeRic = MixStandardRic-BudgetStandardRic
        ScostamentoMixRic = MixEffettivoRic-MixStandardRic
        ScostamentoPrezzoRic = BudgetEffettivoRic-MixEffettivoRic
        ScostamentoValutaRic = BudgetEffettivoValutaRic-BudgetEffettivoRic


        lavorazioniSingoloProdotto = sqldf('select * from x where NrArticolo = "'+articolo+'"')

        #Budget Standard
        BudgetStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y) from lavorazioniSingoloProdotto').iloc[0][0]
        # Impiego Standard (volume a consuntivo)
        ImpiegoStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]
        # Impiego Effettivo (volume e impiego a consuntivo)
        ImpiegoEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_y*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]
        # Budget Effettivo (tutto a consuntivo)
        BudgetEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]

        if(BudgetStandardLav is None):
                        BudgetStandardLav = 0

        if(ImpiegoStandardLav is None):
                        ImpiegoStandardLav = 0

        if(ImpiegoEffettivoLav is None):
                        ImpiegoEffettivoLav = 0

        if(BudgetEffettivoLav is None):
                        BudgetEffettivoLav = 0

        #Scostamenti
        ScostamentoVolumeLav = ImpiegoStandardLav-BudgetStandardLav
        ScostamentoImpiegoLav = ImpiegoEffettivoLav-ImpiegoStandardLav
        ScostamentoPrezzoLav = BudgetEffettivoLav-ImpiegoEffettivoLav

        consumiSingoloArticolo = sqldf('select * from ConsumiUnit where NrArticolo="'+articolo+'"')

        BudgetEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_x) from consumiSingoloArticolo').iloc[0][0]
        ImpiegoEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_y) from consumiSingoloArticolo').iloc[0][0]
        ImpiegoStandardMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from consumiSingoloArticolo').iloc[0][0]
        BudgetStandardMP = sqldf('select sum(QuantitydiOutput_y*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from consumiSingoloArticolo').iloc[0][0]

        #TODO: choose strategy 

        BudgetEffettivoMP = sqldf('select (avg(QuantitydiOutput_x)*avg(ImpiegoPerPezzo_x)*avg(CostoPerUnitaMis_x)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]
        ImpiegoEffettivoMP = sqldf('select (avg(QuantitydiOutput_x)*avg(ImpiegoPerPezzo_x)*avg(CostoPerUnitaMis_y)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]
        ImpiegoStandardMP = sqldf('select (avg(QuantitydiOutput_x)*avg(ImpiegoPerPezzo_y)*avg(CostoPerUnitaMis_y)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]
        BudgetStandardMP = sqldf('select (avg(QuantitydiOutput_y)*avg(ImpiegoPerPezzo_y)*avg(CostoPerUnitaMis_y)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]

        if(BudgetStandardMP is None):
                BudgetStandardMP = 0

        if(ImpiegoStandardMP is None):
                ImpiegoStandardMP = 0

        if(ImpiegoEffettivoMP is None):
                ImpiegoEffettivoMP = 0

        if(BudgetEffettivoMP is None):
                BudgetEffettivoMP = 0

        ScostamentoVolumeMP =  ImpiegoStandardMP - BudgetStandardMP
        ScostamentoImpiegoMP = ImpiegoEffettivoMP-ImpiegoStandardMP
        ScostamentoPrezzoMP = BudgetEffettivoMP-ImpiegoEffettivoMP 

        data = {articolo: ['Ricavi', 'CostiMP', 'CostiLav', 'Margine'], 
                'Budget' : [BudgetStandardRic, BudgetStandardMP,BudgetStandardLav, (BudgetStandardRic - (BudgetStandardMP+BudgetStandardLav))],
                'ScostamentoVolume' : [ScostamentoVolumeRic,ScostamentoVolumeMP,ScostamentoVolumeLav, (ScostamentoVolumeRic - (ScostamentoVolumeMP+ScostamentoVolumeLav))], 
                'MixStandard' : [MixStandardRic, ImpiegoStandardMP,ImpiegoStandardLav, (MixStandardRic - (ImpiegoStandardMP+ImpiegoStandardLav))],
                'ScostamentoMix' : [ScostamentoMixRic,ScostamentoImpiegoMP,ScostamentoImpiegoLav, (ScostamentoMixRic - (ScostamentoImpiegoMP+ScostamentoImpiegoLav))],
                'MixEffettivo' : [MixEffettivoRic, ImpiegoEffettivoMP,ImpiegoEffettivoLav, (MixEffettivoRic - (ImpiegoEffettivoMP+ImpiegoEffettivoLav))],
                'ScostamentoPrezzo' : [ScostamentoPrezzoRic,ScostamentoPrezzoMP,ScostamentoPrezzoLav, (ScostamentoPrezzoRic - (ScostamentoPrezzoMP+ScostamentoPrezzoLav))], 
                'MixValuta' : [BudgetEffettivoRic, BudgetEffettivoMP,BudgetEffettivoLav, (BudgetEffettivoRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
                'ScostamentoValuta' : [ScostamentoValutaRic, 0, 0, (ScostamentoValutaRic - (0+0))],
                'Consuntivo' : [BudgetEffettivoValutaRic, BudgetEffettivoMP, BudgetEffettivoLav, (BudgetEffettivoValutaRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
                'ScostamentoTotale' : [BudgetEffettivoValutaRic-BudgetStandardRic,BudgetEffettivoMP-BudgetStandardMP,BudgetEffettivoLav-BudgetStandardLav, (BudgetEffettivoValutaRic - BudgetStandardRic - (BudgetEffettivoMP-BudgetStandardMP+BudgetEffettivoLav-BudgetStandardLav))]}

        return pd.DataFrame(data)

# %%
by_articolo_full(venditeS1,x,ConsumiUnit,'ART0002240')
# Out:
#   ART0002240      Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
# 0     Ricavi  160.516075          46.772749   207.288824      -46.772745
# 1    CostiMP    7.800000           7.800000    15.600000        1.088372
# 2   CostiLav  242.250000         242.250000   484.500000     -238.000000
# 3    Margine  -89.533925        -203.277251  -292.811176      190.138883
#
#    MixEffettivo  ScostamentoPrezzo   MixValuta  ScostamentoValuta  Consuntivo  \
# 0    160.516080          10.245707  170.761787         -20.674236  150.087551
# 1     16.688372          -0.738372   15.950000           0.000000   15.950000
# 2    246.500000         -21.500000  225.000000           0.000000  225.000000
# 3   -102.672292          32.484079  -70.188213         -20.674236  -90.862449
#
#    ScostamentoTotale
# 0         -10.428525
# 1           8.150000
# 2         -17.250000
# 3          -1.328525

# %%
articolo = 'ART0002240'
articolo = 'ART0000308'
articolo = 'ART0005136'

mergeImpiego = x

venditeSingoloArticolo = sqldf('select * from venditeS1 where NrArticolo = "'+articolo+'"')

BudgetStandardRic = sqldf('select sum(Mix_y*VolumeTotale_y*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
MixStandardRic = sqldf('select sum(Mix_y*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
MixEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_y/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
BudgetEffettivoRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_y)/100000000000 from venditeSingoloArticolo ').iloc[0][0]
BudgetEffettivoValutaRic = sqldf('select sum(Mix_x*VolumeTotale_x*PrezzoUnitario_x/TassoCambioMedio_x)/100000000000 from venditeSingoloArticolo ').iloc[0][0]

if(BudgetStandardRic is None):
        BudgetStandardRic = 0

if(MixStandardRic is None):
        MixStandardRic = 0

if(MixEffettivoRic is None):
        MixEffettivoRic = 0

if(BudgetEffettivoRic is None):
        BudgetEffettivoRic = 0

if(BudgetEffettivoValutaRic is None):
        BudgetEffettivoValutaRic = 0

ScostamentoVolumeRic = MixStandardRic-BudgetStandardRic
ScostamentoMixRic = MixEffettivoRic-MixStandardRic
ScostamentoPrezzoRic = BudgetEffettivoRic-MixEffettivoRic
ScostamentoValutaRic = BudgetEffettivoValutaRic-BudgetEffettivoRic


lavorazioniSingoloProdotto = sqldf('select * from x where NrArticolo = "'+articolo+'"')

#Budget Standard
BudgetStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_y) from lavorazioniSingoloProdotto').iloc[0][0]
# Impiego Standard (volume a consuntivo)
ImpiegoStandardLav = sqldf('select sum(ImpiegoUnitario_y*CostoOrario_y*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]
# Impiego Effettivo (volume e impiego a consuntivo)
ImpiegoEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_y*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]
# Budget Effettivo (tutto a consuntivo)
BudgetEffettivoLav=sqldf('select sum(ImpiegoUnitario_x*CostoOrario_x*QuantitydiOutput_x) from lavorazioniSingoloProdotto').iloc[0][0]

if(BudgetStandardLav is None):
                BudgetStandardLav = 0

if(ImpiegoStandardLav is None):
                ImpiegoStandardLav = 0

if(ImpiegoEffettivoLav is None):
                ImpiegoEffettivoLav = 0

if(BudgetEffettivoLav is None):
                BudgetEffettivoLav = 0

#Scostamenti
ScostamentoVolumeLav = ImpiegoStandardLav-BudgetStandardLav
ScostamentoImpiegoLav = ImpiegoEffettivoLav-ImpiegoStandardLav
ScostamentoPrezzoLav = BudgetEffettivoLav-ImpiegoEffettivoLav

consumiSingoloArticolo = sqldf('select * from ConsumiUnit where NrArticolo="'+articolo+'"')

BudgetEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_x) from consumiSingoloArticolo').iloc[0][0]
ImpiegoEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_y) from consumiSingoloArticolo').iloc[0][0]
ImpiegoStandardMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from consumiSingoloArticolo').iloc[0][0]
BudgetStandardMP = sqldf('select sum(QuantitydiOutput_y*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from consumiSingoloArticolo').iloc[0][0]

#TODO: choose strategy 

BudgetEffettivoMP = sqldf('select (avg(QuantitydiOutput_x)*avg(ImpiegoPerPezzo_x)*avg(CostoPerUnitaMis_x)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]
ImpiegoEffettivoMP = sqldf('select (avg(QuantitydiOutput_x)*avg(ImpiegoPerPezzo_x)*avg(CostoPerUnitaMis_y)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]
ImpiegoStandardMP = sqldf('select (avg(QuantitydiOutput_x)*avg(ImpiegoPerPezzo_y)*avg(CostoPerUnitaMis_y)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]
BudgetStandardMP = sqldf('select (avg(QuantitydiOutput_y)*avg(ImpiegoPerPezzo_y)*avg(CostoPerUnitaMis_y)) from consumiSingoloArticolo group by NrArticolo').iloc[0][0]

if(BudgetStandardMP is None):
        BudgetStandardMP = 0

if(ImpiegoStandardMP is None):
        ImpiegoStandardMP = 0

if(ImpiegoEffettivoMP is None):
        ImpiegoEffettivoMP = 0

if(BudgetEffettivoMP is None):
        BudgetEffettivoMP = 0

ScostamentoVolumeMP =  ImpiegoStandardMP - BudgetStandardMP
ScostamentoImpiegoMP = ImpiegoEffettivoMP-ImpiegoStandardMP
ScostamentoPrezzoMP = BudgetEffettivoMP-ImpiegoEffettivoMP 

data = {'Index': ['Ricavi', 'CostiMP', 'CostiLav', 'Margine'], 
        'Budget' : [BudgetStandardRic, BudgetStandardMP,BudgetStandardLav, (BudgetStandardRic - (BudgetStandardMP+BudgetStandardLav))],
        'ScostamentoVolume' : [ScostamentoVolumeRic,ScostamentoVolumeMP,ScostamentoVolumeLav, (ScostamentoVolumeRic - (ScostamentoVolumeMP+ScostamentoVolumeLav))], 
        'MixStandard' : [MixStandardRic, ImpiegoStandardMP,ImpiegoStandardLav, (MixStandardRic - (ImpiegoStandardMP+ImpiegoStandardLav))],
        'ScostamentoMix' : [ScostamentoMixRic,ScostamentoImpiegoMP,ScostamentoImpiegoLav, (ScostamentoMixRic - (ScostamentoImpiegoMP+ScostamentoImpiegoLav))],
        'MixEffettivo' : [MixEffettivoRic, ImpiegoEffettivoMP,ImpiegoEffettivoLav, (MixEffettivoRic - (ImpiegoEffettivoMP+ImpiegoEffettivoLav))],
        'ScostamentoPrezzo' : [ScostamentoPrezzoRic,ScostamentoPrezzoMP,ScostamentoPrezzoLav, (ScostamentoPrezzoRic - (ScostamentoPrezzoMP+ScostamentoPrezzoLav))], 
        'MixValuta' : [BudgetEffettivoRic, BudgetEffettivoMP,BudgetEffettivoLav, (BudgetEffettivoRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
        'ScostamentoValuta' : [ScostamentoValutaRic, 0, 0, (ScostamentoValutaRic - (0+0))],
        'Consuntivo' : [BudgetEffettivoValutaRic, BudgetEffettivoMP, BudgetEffettivoLav, (BudgetEffettivoValutaRic - (BudgetEffettivoMP+BudgetEffettivoLav))],
        'ScostamentoTotale' : [BudgetEffettivoValutaRic-BudgetStandardRic,BudgetEffettivoMP-BudgetStandardMP,BudgetEffettivoLav-BudgetStandardLav, (BudgetEffettivoValutaRic - BudgetStandardRic - (BudgetEffettivoMP-BudgetStandardMP+BudgetEffettivoLav-BudgetStandardLav))]}

pd.DataFrame(data)
# Out:
#       Index        Budget  ScostamentoVolume   MixStandard  ScostamentoMix  \
# 0    Ricavi  12932.919142        3768.520874  16701.440016    -7967.750215
# 1   CostiMP    694.226733         694.226733   1388.453465     1314.397385
# 2  CostiLav   4877.141333        6460.386726  11337.528059     2081.779451
# 3   Margine   7361.551076       -3386.092584   3975.458492   -11363.927052
#
#    MixEffettivo  ScostamentoPrezzo     MixValuta  ScostamentoValuta  \
# 0   8733.689801        2863.053503  11596.743303        -1094.60554
# 1   2702.850851       16274.438521  18977.289371            0.00000
# 2  13419.307510        8881.716494  22301.024004            0.00000
# 3  -7388.468560      -22293.101512 -29681.570072        -1094.60554
#
#      Consuntivo  ScostamentoTotale
# 0  10502.137763       -2430.781379
# 1  18977.289371       18283.062639
# 2  22301.024004       17423.882671
# 3 -30776.175613      -38137.726689

# %% [markdown]
# ## By CodiceMP

# %%
def by_MP(ConsumiUnit, materiaPrima):
    consumiSingolaMP = sqldf('select * from ConsumiUnit where CodiceMP="'+materiaPrima+'"')
    BudgetEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_x) from consumiSingolaMP').iloc[0][0]
    ImpiegoEffettivoMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_x*CostoPerUnitaMis_y) from consumiSingolaMP').iloc[0][0]
    ImpiegoStandardMP = sqldf('select sum(QuantitydiOutput_x*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from consumiSingolaMP').iloc[0][0]
    BudgetStandardMP = sqldf('select sum(QuantitydiOutput_y*ImpiegoPerPezzo_y*CostoPerUnitaMis_y) from consumiSingolaMP').iloc[0][0]

    if(BudgetStandardMP is None):
                BudgetStandardMP = 0

    if(ImpiegoStandardMP is None):
                ImpiegoStandardMP = 0

    if(ImpiegoEffettivoMP is None):
                ImpiegoEffettivoMP = 0

    if(BudgetEffettivoMP is None):
                BudgetEffettivoMP = 0

    ScostamentoVolumeMP =  ImpiegoStandardMP - BudgetStandardMP
    ScostamentoImpiegoMP = ImpiegoEffettivoMP-ImpiegoStandardMP
    ScostamentoPrezzoMP = BudgetEffettivoMP-ImpiegoEffettivoMP 

    data = {materiaPrima: ['CostiMP'], 
                'Budget' : [BudgetStandardMP],
                'ScostamentoVolume' : [ScostamentoVolumeMP,], 
                'MixStandard' : [ImpiegoStandardMP],
#  0    CostiMP  464.07           -232.035      232.035      -23.419906
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    208.615094         -87.765094     120.85                  0      120.85
#
#     ScostamentoTotale
#  0            -343.22  ,
#    ART0005148  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  751.38           -305.325      446.055      -84.088522
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    361.966478          56.813522     418.78                  0      418.78
#
#     ScostamentoTotale
#  0             -332.6  ,
#    ART0005287  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  295.49            -295.49            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0            -295.49  ,
#    ART0005750  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  291.84            -291.84            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0            -291.84  ,
#    ART0002358  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   288.8             -288.8            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -288.8  ,
#    ART0001872   Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  1162.38                0.0      1162.38             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0       1162.38            -284.12     878.26                  0      878.26
#
#     ScostamentoTotale
#  0            -284.12  ,
#    ART0005712  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  436.89                0.0       436.89      -295.91037
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     140.97963           26.64037     167.62                  0      167.62
#
#     ScostamentoTotale
#  0            -269.27  ,
#    ART0001929  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  649.14                0.0       649.14         -324.57
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0        324.57              72.55     397.12                  0      397.12
#
#     ScostamentoTotale
#  0            -252.02  ,
#    ART0001900  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  376.41           -188.205      188.205             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0       188.205            -56.315     131.89                  0      131.89
#
#     ScostamentoTotale
#  0            -244.52  ,
#    ART0001789  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  491.17           -245.585      245.585             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    CostiMP  418.74                0.0       418.74             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0        418.74             -135.3     283.44                  0      283.44
#
#     ScostamentoTotale
#  0             -135.3  ,
#    ART0005651  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   132.0             -132.0            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -132.0  ,
#    ART0005409  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  172.12         -86.726667    85.393333      -42.018005
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     43.375328          -0.005328      43.37                  0       43.37
#
#     ScostamentoTotale
#  0            -128.75  ,
#    ART0005759  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  120.25            -120.25            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0            -120.25  ,
#    ART0005285  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  109.57            -109.57            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0            -109.57  ,
#    ART0005453  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  185.36             -92.68        92.68           -66.2
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0         26.48              52.96      79.44                  0       79.44
#
#     ScostamentoTotale
#  0            -105.92  ,
#    ART0001820  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  248.78                0.0       248.78         -124.39
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0        124.39              18.97     143.36                  0      143.36
#
#     ScostamentoTotale
#  0            -105.42  ,
#    ART0005348  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  104.47            -104.47            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0            -104.47  ,
#    ART0005468  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  164.27           -145.255       19.015          2.2818
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0       21.2968            39.5332      60.83                  0       60.83
#
#     ScostamentoTotale
#  0            -103.44  ,
#    ART0005234  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   99.55             -99.55            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    279.675657          42.234343     321.91                  0      321.91
#
#     ScostamentoTotale
#  0             -81.12  ,
#    ART0005246  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   80.36             -80.36            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -80.36  ,
#    ART0004148  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  233.03          -184.9975      48.0325          -23.52
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0       24.5125           130.0775     154.59                  0      154.59
#
#     ScostamentoTotale
#  0             -78.44  ,
#    ART0005693  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   156.0              -78.0         78.0             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0          78.0                0.0       78.0                  0        78.0
#
#     ScostamentoTotale
#  0              -78.0  ,
#    ART0002020  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  166.15        -110.766667    55.383333             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     55.383333          33.686667      89.07                  0       89.07
#
#     ScostamentoTotale
#  0             -77.08  ,
#    ART0005467  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    77.0              -77.0            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -77.0  ,
#    ART0005165  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  900.41           -246.742      653.668      159.903792
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    813.571792          11.258208     824.83                  0      824.83
#
#     ScostamentoTotale
#  0             -75.58  ,
#    ART0005423  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   74.67             -74.67            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -74.67  ,
#    ART0005933  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   330.0               18.0        348.0             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0         348.0              -91.8      256.2                  0       256.2
#
#     ScostamentoTotale
#  0              -73.8  ,
#    ART0001874  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  282.51                0.0       282.51             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0        282.51             -71.71      210.8                  0       210.8
#
#     ScostamentoTotale
#  0             -71.71  ,
#    ART0005168  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  167.88             -28.99       138.89      -39.963731
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     98.926269          -2.556269      96.37                  0       96.37
#
#     ScostamentoTotale
#  0             -71.51  ,
#    ART0001884   Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  1958.51          -1370.957      587.553     1248.550125
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0   1836.103125          51.566875    1887.67                  0     1887.67
#
#     ScostamentoTotale
#  0             -70.84  ,
#    ART0005259  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    74.0              -60.0         14.0            -6.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0           8.0               -3.0        5.0                  0         5.0
#
#     ScostamentoTotale
#  0              -69.0  ,
#    ART0005232  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    78.7             -53.39        25.31      -14.252133
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     11.057867           0.442133       11.5                  0        11.5
#
#     ScostamentoTotale
#  0              -67.2  ,
#    ART0002096  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    67.0              -67.0            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -67.0  ,
#    ART0005682  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    99.0              -49.5         49.5           -16.5
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0          33.0                1.5       34.5                  0        34.5
#
#     ScostamentoTotale
#  0              -64.5  ,
#    ART0005610  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    62.4              -62.4            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -62.4  ,
#    ART0005469  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   60.37             -60.37            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -60.37  ,
#    ART0002120  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   71.23         -47.486667    23.743333             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     23.743333         -11.153333      12.59                  0       12.59
#
#     ScostamentoTotale
#  0             -58.64  ,
#    ART0005162  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   57.98             -57.98            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -57.98  ,
#    ART0001767  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  131.94                0.0       131.94          -65.97
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0         65.97               9.93       75.9                  0        75.9
#
#     ScostamentoTotale
#  0             -56.04  ,
#    ART0002609  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  137.72                0.0       137.72             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0        137.72             -54.72       83.0                  0        83.0
#
#     ScostamentoTotale
#  0             -54.72  ,
#    ART0001765   Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  1820.01       -1120.006154   700.003846     1120.006154
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0       1820.01              -53.3    1766.71                  0     1766.71
#
#     ScostamentoTotale
#  0              -53.3  ,
#    ART0005549  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    51.0              -51.0            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -51.0  ,
#    ART0005324  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   48.96             -48.96            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -48.96  ,
#    ART0005211  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    60.0                0.0         60.0           -48.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0          12.0                0.0       12.0                  0        12.0
#
#     ScostamentoTotale
#  0              -48.0  ,
#    ART0001390  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    50.0              -25.0         25.0             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0          25.0              -22.0        3.0                  0         3.0
#
#     ScostamentoTotale
#  0              -47.0  ,
#    ART0005158  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   46.78             -46.78            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -46.78  ,
#    ART0005457  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   46.11             -46.11            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -46.11  ,
#    ART0005634  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   44.71             -44.71            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -44.71  ,
#    ART0005879  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    72.0               36.0        108.0             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0         108.0              -79.5       28.5                  0        28.5
#
#     ScostamentoTotale
#  0              -43.5  ,
#    ART0004155  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   49.95              -40.5         9.45           -4.05
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0           5.4               1.35       6.75                  0        6.75
#
#     ScostamentoTotale
#  0              -43.2  ,
#    ART0005239  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   75.17              -12.4        62.77      -30.687556
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     32.082444          -0.002444      32.08                  0       32.08
#
#     ScostamentoTotale
#  0             -43.09  ,
#    ART0005920  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    56.0              -14.0         42.0             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0          42.0              -28.0       14.0                  0        14.0
#
#     ScostamentoTotale
#  0              -42.0  ,
#    ART0005664  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   266.7            -73.975      192.725        6.104216
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    198.829216          27.290784     226.12                  0      226.12
#
#     ScostamentoTotale
#  0             -40.58  ,
#    ART0005349  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   39.73             -39.73            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -39.73  ,
#    ART0005667  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   35.03             -35.03            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -35.03  ,
#    ART0005190  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   59.61         -27.979231    31.630769       -6.343945
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     25.286825           1.083175      26.37                  0       26.37
#
#     ScostamentoTotale
#  0             -33.24  ,
#    ART0005245  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   41.91             -41.91            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0              10.13      10.13                  0       10.13
#
#     ScostamentoTotale
#  0             -31.78  ,
#    ART0005633  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    31.0              -31.0            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -31.0  ,
#    ART0005623  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    30.0              -30.0            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -30.0  ,
#    ART0005779  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    33.0                0.0         33.0             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0          33.0              -29.6        3.4                  0         3.4
#
#     ScostamentoTotale
#  0              -29.6  ,
#    ART0005788  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    56.0                0.0         56.0           -28.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0          28.0                0.0       28.0                  0        28.0
#
#     ScostamentoTotale
#  0              -28.0  ,
#    ART0005335  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   33.56         -24.797111     8.762889       -1.752578
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0      7.010311          -0.540311       6.47                  0        6.47
#
#     ScostamentoTotale
#  0             -27.09  ,
#    ART0005471  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   26.88             -26.88            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -26.88  ,
#    ART0001987  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   50.68                0.0        50.68           50.68
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0        101.36             -76.36       25.0                  0        25.0
#
#     ScostamentoTotale
#  0             -25.68  ,
#    ART0001083  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   69.27          -20.92875     48.34125       -1.022523
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     47.318727          -3.328727      43.99                  0       43.99
#
#     ScostamentoTotale
#  0             -25.28  ,
#    ART0005277  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   24.58             -24.58            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -24.58  ,
#    ART0005159  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   24.54             -24.54            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -24.54  ,
#    ART0005341  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   28.48             -28.48            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0               5.25       5.25                  0        5.25
#
#     ScostamentoTotale
#  0             -23.23  ,
#    ART0005339  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   26.22             -26.22            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                3.3        3.3                  0         3.3
#
#     ScostamentoTotale
#  0             -22.92  ,
#    ART0005815  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    22.0              -22.0            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -22.0  ,
#    ART0005291  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   31.77             -13.77         18.0       -7.819108
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     10.180892           0.039108      10.22                  0       10.22
#
#     ScostamentoTotale
#  0             -21.55  ,
#    ART0005886  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   19.94             -19.94            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -19.94  ,
#    ART0005568  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   46.83             -12.85        33.98             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0         33.98              -7.03      26.95                  0       26.95
#
#     ScostamentoTotale
#  0             -19.88  ,
#    ART0005855  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   33.87             -22.58        11.29             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0         11.29               3.03      14.32                  0       14.32
#
#     ScostamentoTotale
#  0             -19.55  ,
#    ART0001836  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  140.02                0.0       140.02             0.0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0        140.02             -18.92      121.1                  0       121.1
#
#     ScostamentoTotale
#  0             -18.92  ,
#    ART0005537  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   18.02             -18.02            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -18.02  ,
#    ART0005410  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   16.51             -16.51            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0             -16.51  ,
#    ART0005164  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   70.24             -16.97        53.27        0.665875
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     53.935875           0.004125      53.94                  0       53.94
#
#     ScostamentoTotale
#  0              -16.3  ,
#    ART0005543  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   87.52             -13.61        73.91        6.006233
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0     79.916233          -8.606233      71.31                  0       71.31
#
#     ScostamentoTotale
#  0             -16.21  ,
#    ART0005417  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    16.2              -16.2            0               0
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0             0                  0          0                  0           0
#
#     ScostamentoTotale
#  0              -16.2  ,
#    ART0001426  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP    62.5                0.0         62.5       71.428571
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    133.928571         -87.038571      46.89                  0       46.89
#
#     ScostamentoTotale
#  0             -15.61  ,
#    ART0001082  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  350.15         -11.110182   339.039818     -124.049846
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0    214.989972         119.660028     334.65                  0      334.65
#
# ...
#
#     ScostamentoTotale
#  0             731.81  ,
#    ART0005560  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  383.66          99.526667   483.186667      662.158098
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0   1145.344765         -20.664765    1124.68                  0     1124.68
#
#     ScostamentoTotale
#  0             741.02  ,
#    ART0001898  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  4230.6         519.716667  4750.316667     1138.768333
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0      5889.085           -853.665    5035.42                  0     5035.42
#
#     ScostamentoTotale
#  0             804.82  ,
#    ART0001777  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP   79.34             634.72       714.06           396.7
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0       1110.76            -224.53     886.23                  0      886.23
#
#     ScostamentoTotale
#    ART0001940   Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  2352.81           1176.405     3529.215         4705.62
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0      8234.835          -1886.985    6347.85                  0     6347.85
#
#     ScostamentoTotale
#  0            3995.04  ,
#    ART0001770  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  240.59             962.36      1202.95     3689.046667
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0   4891.996667         369.443333    5261.44                  0     5261.44
#
#     ScostamentoTotale
#  0            5020.85  ,
#    ART0001756   Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  4362.04           2617.224     6979.264     5515.021427
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0  12494.285427       -1948.085427    10546.2                  0     10546.2
#
#     ScostamentoTotale
#  0            6184.16  ,
#    ART0001883  Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  400.37            1601.48      2001.85     6139.006667
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0   8140.856667         189.923333    8330.78                  0     8330.78
#
#     ScostamentoTotale
#  0            7930.41  ,
#    ART0001868   Budget  ScostamentoVolume  MixStandard  ScostamentoMix  \
#  0    CostiMP  5247.37           3148.422     8395.792     6634.363276
#
#     MixEffettivo  ScostamentoPrezzo  MixValuta  ScostamentoValuta  Consuntivo  \
#  0  15030.155276        -961.075276   14069.08                  0    14069.08
#
#     ScostamentoTotale
#  0            8821.71  ]

# %% [markdown]
# # Scratchpad

# %%
y = sqldf('select NrArticolo,count(descrizione) from impiegoBudget1 group by NrArticolo having Descrizione = "Controllo qualità" or Descrizione = "Montaggio"')
y
# Out:
#      NrArticolo  count(descrizione)
# 0    ART0000018                   3
# 1    ART0000041                   3
# 2    ART0000042                   3
# 3    ART0000121                   1
# 4    ART0000125                   7
# ..          ...                 ...
# 432  ART0005109                   2
# 433  ART0005110                   1
# 434  ART0005111                   2
# 435  ART0005112                   2
# 436  ART0005136                  60
#
# [437 rows x 2 columns]

# %%
x = sqldf('select NrArticolo,count(descrizione) from impiegoBudget1 group by NrArticolo')
x
# Out:
#      NrArticolo  count(descrizione)
# 0    ART0000018                   3
# 1    ART0000041                   3
# 2    ART0000042                   3
# 3    ART0000043                   4
# 4    ART0000115                   2
# ..          ...                 ...
# 499  ART0005109                   2
# 500  ART0005110                   1
# 501  ART0005111                   2
# 502  ART0005112                   2
# 503  ART0005136                  60
#
# [504 rows x 2 columns]

# %%
sqldf ('select NrArticolo from x where NrArticolo not in (select NrArticolo from y)')
# Out:
#     NrArticolo
# 0   ART0000043
# 1   ART0000115
# 2   ART0000116
# 3   ART0000119
# 4   ART0000157
# ..         ...
# 62  ART0004363
# 63  ART0004836
# 64  ART0004886
# 65  ART0004941
# 66  ART0005026
#
# [67 rows x 1 columns]
